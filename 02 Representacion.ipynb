# %% [markdown]
# **NLP**
#
# *CC6205-1 - Otoño 2022*
#
# Autor: Felipe Urrutia Vargas

# %%
# !pip install --upgrade pandas

import pandas as pd
import numpy as np
# pd.set_option("max_rows", None)
import pickle
from string import punctuation
import re

from sklearn.metrics import cohen_kappa_score
import matplotlib.pyplot as plt
import seaborn as sns
# from astropy.visualization import hist
sns.set_theme(style="whitegrid")
plt.rc('axes', titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)
plt.rcParams.update({'font.size': 16})
plt.rcParams['axes.titlesize'] = 16
plt.rcParams["figure.figsize"] = (10, 6)
plt.rcParams.update({'lines.markeredgewidth': 1})
plt.rcParams.update({'errorbar.capsize': 2})
import random

import plotly.express as px

# %%
df_train = pickle.load(open("df_train.pickle", "rb"))

# %%
#import spacy library
import spacy

# !python -m spacy download en_core_web_sm

nlp = spacy.load("en_core_web_sm")
# Out:
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in c:\users\felip\anaconda3\lib\site-packages (from en-core-web-sm==3.2.0) (3.2.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\felip\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\felip\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\felip\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.7.5)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\felip\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\felip\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\felip\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\felip\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\felip\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\felip\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.27.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\felip\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\felip\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.62.3)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\felip\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\felip\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\felip\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\felip\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.0)
# Requirement already satisfied: jinja2 in c:\users\felip\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.11.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\felip\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.13)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\felip\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\felip\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: setuptools in c:\users\felip\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (58.0.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\felip\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\felip\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\felip\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.10.0.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\felip\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\felip\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\felip\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\felip\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3)
# Requirement already satisfied: colorama in c:\users\felip\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\felip\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\felip\anaconda3\lib\site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
vocab_joy = {i: [] for i in intensities}
for i in intensities:
    _sub = df_train[(df_train["sen"] == "joy") & (df_train["int"] == i)]
    for text in _sub["text"]:
        doc = nlp(text)
        for t in doc:
            vocab_joy[i].append(t.text.lower())

# %%
import collections

# %%
frequencyDict = collections.Counter(vocab_joy["low"])
sorted(frequencyDict.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('.', 122),
#  ('the', 118),
#  (',', 100),
#  ('i', 99),
#  ('#', 87),
#  ('to', 83),
#  ('a', 81),
#  ('and', 65),
#  ('of', 55),
#  ('is', 45),
#  ('it', 41),
#  ("'s", 40),
#  ('be', 40),
#  ('that', 39),
#  ('in', 38),
#  ('you', 38),
#  ("'", 38),
#  ('...', 35),
#  ("n't", 29),
#  ('but', 28),
#  ('with', 27),
#  ('me', 27),
#  ('on', 24),
#  ('my', 23),
#  ('for', 22),
#  ('just', 20),
#  ('do', 19),
#  ('when', 19),
#  ('so', 19),
#  ('at', 19),
#  ('up', 18),
#  ('they', 18),
#  (';', 18),
#  ('-', 18),
#  ('all', 18),
#  ('?', 17),
#  ('like', 17),
#  ('was', 17),
#  ('!', 17),
#  ('he', 16),
#  ('your', 16),
#  ('or', 16),
#  ('not', 16),
#  ('if', 15),
#  ('are', 15),
#  ('out', 14),
#  ('this', 14),
#  ('will', 13),
#  ('no', 13),
#  ('&', 13),
#  ('glee', 13),
#  ('about', 13),
#  ('who', 13),
#  ('as', 12),
#  ('animated', 12),
#  ('would', 12),
#  ('from', 12),
#  ('we', 12),
#  ("'re", 12),
#  ('optimism', 11),
#  ('some', 11),
#  ('way', 11),
#  (':', 11),
#  ('have', 11),
#  ('were', 10),
#  ('she', 10),
#  ('u', 10),
#  ('chirp', 10),
#  ('sparkling', 10),
#  (':(', 9),
#  ('cheer', 9),
#  ('people', 9),
#  ('want', 8),
#  ('our', 8),
#  ('an', 8),
#  ('get', 8),
#  ('one', 8),
#  ('why', 8),
#  ('can', 8),
#  ('over', 8),
#  ('bright', 7),
#  ('see', 7),
#  ('his', 7),
#  ('him', 7),
#  ('too', 7),
#  ('heyday', 7),
#  ("'m", 7),
#  ('then', 7),
#  ('could', 7),
#  ('_', 7),
#  ('new', 7),
#  ('because', 7),
#  ('gleeful', 7),
#  ('by', 7),
#  ('their', 7),
#  ('rejoicing', 7),
#  (':)', 7),
#  ('has', 7),
#  ('how', 7),
#  ('had', 7),
#  ('day', 7),
#  ('night', 6),
#  (' ', 6),
#  ('work', 6),
#  ('us', 6),
#  ('going', 6),
#  ('them', 6),
#  ('really', 6),
#  ('only', 6),
#  ('levity', 6),
#  ('did', 6),
#  ('lively', 6),
#  ('good', 6),
#  ('know', 6),
#  ('nt', 6),
#  ('cheery', 6),
#  ('watch', 6),
#  ('there', 6),
#  ('always', 6),
#  ('never', 6),
#  ('amp', 6),
#  ('%', 6),
#  ('water', 6),
#  ('still', 6),
#  ('2', 6),
#  ('playful', 5),
#  ('maybe', 5),
#  ('now', 5),
#  ('after', 5),
#  ('home', 5),
#  ('before', 5),
#  ('try', 5),
#  ('makes', 5),
#  ('happy', 5),
#  ('fans', 5),
#  ('cheering', 5),
#  ('does', 5),
#  ('days', 5),
#  ('back', 5),
#  ('hearty', 5),
#  ('n', 5),
#  ('cheerful', 5),
#  ('fucking', 5),
#  ('am', 5),
#  ('even', 5),
#  ('bad', 4),
#  ('laughter', 4),
#  ('through', 4),
#  ('love', 4),
#  ('while', 4),
#  ('looks', 4),
#  ('take', 4),
#  ('light', 4),
#  ('myself', 4),
#  ('more', 4),
#  ('than', 4),
#  ('pleasing', 4),
#  ('mirth', 4),
#  ('cheerfully', 4),
#  ('own', 4),
#  ('give', 4),
#  ('ca', 4),
#  ('look', 4),
#  ('man', 4),
#  ('off', 4),
#  ('need', 4),
#  ('boy', 4),
#  ('tears', 4),
#  ('life', 4),
#  ('think', 4),
#  ('actually', 4),
#  ('someone', 4),
#  ('those', 4),
#  ('time', 4),
#  ('saw', 4),
#  ('tell', 4),
#  ('bit', 4),
#  ('..', 4),
#  ('its', 4),
#  ('two', 4),
#  ('🤔', 4),
#  ("'ve", 4),
#  ('jovial', 4),
#  ('last', 4),
#  ('smile', 4),
#  ('sad', 4),
#  ('tv', 4),
#  ('being', 3),
#  ('jubilant', 3),
#  ('away', 3),
#  ('delight', 3),
#  ('come', 3),
#  ('side', 3),
#  ('feel', 3),
#  ('misery', 3),
#  ('well', 3),
#  ('use', 3),
#  ('most', 3),
#  ('support', 3),
#  ('into', 3),
#  ('either', 3),
#  ('wish', 3),
#  ('smiling', 3),
#  ('make', 3),
#  ('which', 3),
#  ('wanna', 3),
#  ('buy', 3),
#  ('(', 3),
#  (')', 3),
#  ('rejoice', 3),
#  ('e', 3),
#  ('die', 3),
#  ('put', 3),
#  ('truly', 3),
#  ('things', 3),
#  ('wanted', 3),
#  ('drink', 3),
#  ('worst', 3),
#  ('sometimes', 3),
#  ('top', 3),
#  ('cluck', 3),
#  ('wolf', 3),
#  ('used', 3),
#  ('wrong', 3),
#  ('started', 3),
#  ('down', 3),
#  ('pity', 3),
#  ('joyous', 3),
#  ('called', 3),
#  ('tweet', 3),
#  ('m', 3),
#  ('sit', 3),
#  ('other', 3),
#  ('anyone', 3),
#  ('any', 3),
#  ('spry', 3),
#  ('shut', 3),
#  ('quite', 3),
#  ('....', 3),
#  ('breezy', 3),
#  ('month', 3),
#  ('amp;&amp', 3),
#  ('full', 3),
#  ('trans', 3),
#  ('week', 3),
#  ('tumblr', 3),
#  ('gif', 3),
#  ('trump', 3),
#  ('here', 3),
#  ('short', 3),
#  ('quinn', 3),
#  ('within', 3),
#  ('na', 3),
#  ('got', 3),
#  ('hate', 3),
#  ('7', 3),
#  ('world', 3),
#  ('something', 3),
#  ('@jackcurryyes', 2),
#  ('lucky', 2),
#  ('pitchers', 2),
#  ('#whatever', 2),
#  ('elkracken', 2),
#  ('legit', 2),
#  ('future', 2),
#  ('gottawearshades', 2),
#  ('letsgoyankees', 2),
#  ('shit', 2),
#  ('wo', 2),
#  ('miss', 2),
#  ('@realdonaldtrump', 2),
#  ('hear', 2),
#  ('word', 2),
#  ('@blackeyed_susie', 2),
#  ('ai', 2),
#  ('hurt', 2),
#  ('changing', 2),
#  ('hearts', 2),
#  ('/', 2),
#  ('minds', 2),
#  ('option', 2),
#  ('dog', 2),
#  ('face', 2),
#  ('ring', 2),
#  ('such', 2),
#  ('long', 2),
#  ('children', 2),
#  ('baby', 2),
#  ('15', 2),
#  ('*', 2),
#  ('lot', 2),
#  ('backed', 2),
#  ('pats', 2),
#  ('-2.5', 2),
#  ('10/11', 2),
#  ('assured', 2),
#  ('eventual', 2),
#  ('destruction', 2),
#  ('interests', 2),
#  ('public', 2),
#  ('accept', 2),
#  ('mean', 2),
#  ('without', 2),
#  ('corridor', 2),
#  ('liveliness', 2),
#  ('go', 2),
#  ('should', 2),
#  ('mom', 2),
#  ('bet', 2),
#  ('episodes', 2),
#  ('young', 2),
#  ('year', 2),
#  ('drop', 2),
#  ('kind', 2),
#  ('hilarity', 2),
#  ('experience', 2),
#  ('during', 2),
#  ('date', 2),
#  ('find', 2),
#  ('child', 2),
#  ('grow', 2),
#  ('ten', 2),
#  ('bass', 2),
#  ('may', 2),
#  ('book', 2),
#  ('real', 2),
#  ('money', 2),
#  ('@hillaryclinton', 2),
#  ('enough', 2),
#  ('@mark_slifer', 2),
#  ('supposed', 2),
#  ('donation', 2),
#  ('saved', 2),
#  ('lives', 2),
#  ('draw', 2),
#  ('must', 2),
#  ('utd', 2),
#  ('right', 2),
#  ('yourself', 2),
#  ('ever', 2),
#  ('policy', 2),
#  ('score', 2),
#  ('drinking', 2),
#  ('talk', 2),
#  ('church', 2),
#  ('every', 2),
#  ('research', 2),
#  ('10', 2),
#  ('gt', 2),
#  ('sick', 2),
#  ('describe', 2),
#  ('character', 2),
#  ('teams', 2),
#  ('[', 2),
#  ('though', 2),
#  ('said', 2),
#  ('jaunty', 2),
#  ('told', 2),
#  ('singing', 2),
#  ('pakistan', 2),
#  ('halfway', 2),
#  ('realize', 2),
#  ('forgot', 2),
#  ('underwear', 2),
#  ('mombrain', 2),
#  ('toomuchgoingon', 2),
#  ('longday', 2),
#  ('three', 2),
#  ('ex', 2),
#  ('wives', 2),
#  ('worse', 2),
#  ('oilandgas', 2),
#  ('today', 2),
#  ('again', 2),
#  ('broken', 2),
#  ('another', 2),
#  ('company', 2),
#  ('where', 2),
#  ('care', 2),
#  ('@berniedole', 2),
#  ('let', 2),
#  ('rohan', 2),
#  ('70', 2),
#  ('anxiety', 2),
#  ("'ll", 2),
#  ('🐑', 2),
#  ('break', 2),
#  ('😭', 2),
#  ('😢', 2),
#  ('remember', 2),
#  ('john', 2),
#  ('done', 2),
#  ('memories', 2),
#  ('clear', 2),
#  ('getting', 2),
#  ('everyone', 2),
#  ('wave', 2),
#  ('etep', 2),
#  ('elated', 2),
#  ('buoyant', 2),
#  ('cheerfulness', 2),
#  ('cut', 2),
#  ('“', 2),
#  ('pause', 2),
#  ('”', 2),
#  ('haters', 2),
#  ('everything', 2),
#  ('joyful', 2),
#  ('ceased', 2),
#  ('heart', 2),
#  ('against', 2),
#  ('lost', 2),
#  ('genocide', 2),
#  ('don', 2),
#  ('king', 2),
#  ("'d", 2),
#  ('thought', 2),
#  ('😕', 2),
#  ('oh', 2),
#  ('wonder', 2),
#  ('answer', 2),
#  ('y', 2),
#  ('what', 2),
#  ('😔', 2),
#  ('dt', 2),
#  ('news', 2),
#  ('afghanistan', 2),
#  ('felt', 2),
#  ('lol', 2),
#  ('person', 2),
#  ('expect', 2),
#  ('her', 2),
#  ('imagine', 2),
#  ('say', 2),
#  ('ribena', 2),
#  ('death', 2),
#  ('r', 2),
#  ('cake', 2),
#  ('😒', 2),
#  ('shitty', 2),
#  ('reinforce', 2),
#  ('giving', 2),
#  ('cuz', 2),
#  ('awful', 2),
#  ('stand', 2),
#  ('chance', 2),
#  ('annoyed', 2),
#  ('outside', 2),
#  ('hair', 2),
#  ('gon', 2),
#  ('thinks', 2),
#  ('respond', 2),
#  ('email', 2),
#  ('killed', 2),
#  ('girl', 2),
#  ('😤', 1),
#  ('final', 1),
#  ('shift', 1),
#  ('coming', 1),
#  ('pals', 1),
#  ('hysterical', 1),
#  ('gets', 1),
#  ('@colmorrisdavis', 1),
#  ('@rolling_2', 1),
#  ('@pbump', 1),
#  ('probably', 1),
#  ('uses', 1),
#  ('secret', 1),
#  ('heard', 1),
#  ('loud', 1),
#  ('scratched', 1),
#  ('flailing', 1),
#  ('paws', 1),
#  ('excitement', 1),
#  ('almost', 1),
#  ('tore', 1),
#  ('nose', 1),
#  ('@fillegrossiere', 1),
#  ('@peasparsley', 1),
#  ('@tombrodude', 1),
#  ('bobs', 1),
#  ('burgers', 1),
#  ('show', 1),
#  ('bob', 1),
#  ('cast', 1),
#  ('based', 1),
#  ('voice', 1),
#  ('strange', 1),
#  ('seeing', 1),
#  ('mark', 1),
#  ('hughes', 1),
#  ('struggle', 1),
#  ('@malyoung', 1),
#  ('@angelicamcd', 1),
#  ('hope', 1),
#  ('romance', 1),
#  ('happiness', 1),
#  ('stitch', 1),
#  ('abby', 1),
#  ('hard', 1),
#  ('road', 1),
#  ('youtube', 1),
#  ('heroes', 1),
#  ('leafy', 1),
#  ('finally', 1),
#  ('banned', 1),
#  ('despite', 1),
#  ('absolute', 1),
#  ('having', 1),
#  ('kitten', 1),
#  ('husband', 1),
#  ('@colmjoconnor', 1),
#  ('afraid', 1),
#  ('expecting', 1),
#  ('1st', 1),
#  ('reckon', 1),
#  ('aged', 1),
#  ('gulps', 1),
#  ('old', 1),
#  (':-)', 1),
#  ('@kmunie7', 1),
#  ('@karanesch', 1),
#  ('helluva', 1),
#  ('actual', 1),
#  ('game', 1),
#  ('gt;.&lt', 1),
#  ('loading', 1),
#  ('trusted', 1),
#  ('websites', 1),
#  ('lkskqufke', 1),
#  ('@foxtv', 1),
#  ('warblers', 1),
#  ('set', 1),
#  ('@bonesonfox', 1),
#  ('episode', 1),
#  ('acapella', 1),
#  ('college', 1),
#  ('kids', 1),
#  ('-sherlock', 1),
#  ('holmes-', 1),
#  ('gkn', 1),
#  ('mad', 1),
#  ('quick', 1),
#  ('@adamcimmering', 1),
#  ('boro', 1),
#  ('os', 1),
#  ('stewards', 1),
#  ('chelsea', 1),
#  ('8k', 1),
#  ('guess', 1),
#  ('ones', 1),
#  ('treated', 1),
#  ('yoosung', 1),
#  ('dating', 1),
#  ('method', 1),
#  ('thin', 1),
#  ('assault', 1),
#  ('thine', 1),
#  ('chd', 1),
#  ('@niceonewern', 1),
#  ('@alotta_pain', 1),
#  ('gleesome', 1),
#  ('threesome', 1),
#  ('@eachus', 1),
#  ('least', 1),
#  ('willing', 1),
#  ('discuss', 1),
#  ('better', 1),
#  ('keep', 1),
#  ('insults', 1),
#  ('occasional', 1),
#  ('creative', 1),
#  ('bs', 1),
#  ('ing', 1),
#  ('@flutterpolitely', 1),
#  ('80', 1),
#  ('-could', 1),
#  ('writing', 1),
#  ('stronger', 1),
#  ('sacrificed', 1),
#  ('first', 1),
#  ('stack', 1),
#  ('porthole', 1),
#  ('under', 1),
#  ('worthy', 1),
#  ('faith', 1),
#  ("bull's", 1),
#  ('eye', 1),
#  ('transportation', 1),
#  ('services', 1),
#  ('dat', 1),
#  ('eating', 1),
#  ('name', 1),
#  ('brand', 1),
#  ('cheerios', 1),
#  ('relate', 1),
#  ('eat', 1),
#  ('o', 1),
#  ('found', 1),
#  ('rope', 1),
#  ('tipstosurviveapoweroutage', 1),
#  ('@hoemanda69', 1),
#  ('wtf', 1),
#  ('tenacious', 1),
#  ('dark', 1),
#  ('dense', 1),
#  ('exhilarating', 1),
#  ('finale', 1),
#  ('hellorhighwater', 1),
#  ('gripping', 1),
#  ('unlimited', 1),
#  ('forever', 1),
#  ('gleegoodbye', 1),
#  ('very', 1),
#  ('compiled', 1),
#  ('info', 1),
#  ('mattress', 1),
#  ('created', 1),
#  ('evil', 1),
#  ('question', 1),
#  ('cheerleaders', 1),
#  ('ages', 1),
#  ('out!!\\nhow', 1),
#  ('senior', 1),
#  ('memorable', 1),
#  ('@_kdddd', 1),
#  ('1133', 1),
#  ('leads', 1),
#  ('average', 1),
#  ('especially', 1),
#  ('breakups', 1),
#  ('hms', 1),
#  ('pinafore', 1),
#  ('time.\\n\\ni', 1),
#  ('@orbsofjoy', 1),
#  ('plan', 1),
#  ('smth', 1),
#  ('fuckign\\n\\n10/10', 1),
#  ('@johnwintertweet', 1),
#  ('dudes', 1),
#  ('play', 1),
#  ('@lennyabrahamson', 1),
#  ('send', 1),
#  ('copy', 1),
#  ('herothegreyhound', 1),
#  ('paper', 1),
#  ('greyhound', 1),
#  ('smiles', 1),
#  ('@cnbcfastmoney', 1),
#  ('harwood', 1),
#  ('these', 1),
#  ('numbers', 1),
#  ('reporting', 1),
#  ('lose', 1),
#  ('liarthiefscoundrel', 1),
#  ('sherlock', 1),
#  ('holmes', 1),
#  ('@mehnazt', 1),
#  ('@mel_harder', 1),
#  ('live', 1),
#  ('devoid', 1),
#  ('taco', 1),
#  ('bowls', 1),
#  ('amazing', 1),
#  ('live.ly', 1),
#  ('broadcast', 1),
#  ('@haythatjamile8', 1),
#  ('musically', 1),
#  ('@_j_sa', 1),
#  ('switch', 1),
#  ('steve', 1),
#  ('carrell', 1),
#  ('kurt', 1),
#  ('accurate', 1),
#  ('drown', 1),
#  ('gifts', 1),
#  ('materialistic', 1),
#  ('scum', 1),
#  ('rubbing', 1),
#  ('hands', 1),
#  ('typical', 1),
#  ('woolwich', 1),
#  ('jammygunnerscum', 1),
#  ('next', 1),
#  ('round', 1),
#  ('\\nare', 1),
#  ('northampton', 1),
#  ('now?\\n#lufc', 1),
#  ('@flanneljedi', 1),
#  ('likes', 1),
#  ('ride', 1),
#  ('arround', 1),
#  ('shoulders', 1),
#  ('unexpectedly', 1),
#  ('vents', 1),
#  ('doorjambs', 1),
#  ('big', 1),
#  ('spider', 1),
#  ('@crumpledlinen', 1),
#  ('@lebatardshow', 1),
#  ('race', 1),
#  ('war', 1),
#  ('2016', 1),
#  ('@buzzlightbeard2', 1),
#  ('honesty', 1),
#  ('best', 1),
#  ('listening', 1),
#  ('oblivion', 1),
#  ('coffee', 1),
#  ('researching', 1),
#  ('sci', 1),
#  ('fi', 1),
#  ('project', 1),
#  ('@lilymooregrant', 1),
#  ('hoe', 1),
#  ('@cnn', 1),
#  ('@donlemon', 1),
#  ('ovet', 1),
#  ('charlotte', 1),
#  ('protests', 1),
#  ('\\n#northcarolina', 1),
#  ('342:147', 1),
#  ('waxen', 1),
#  ('neeze', 1),
#  ('swear\\na', 1),
#  ('merrier', 1),
#  ('hour', 1),
#  ('wasted', 1),
#  ('there.--\\n#amndbots', 1),
#  ('@sxmurbanview', 1),
#  ('@karenhunter', 1),
#  ('@cousinsyl', 1),
#  ('this!needed', 1),
#  ('recording', 1),
#  ('stress', 1),
#  ('@honevbee', 1),
#  ('close', 1),
#  ('shots', 1),
#  ('ugly', 1),
#  ('mug', 1),
#  ('continue', 1),
#  ('blaine', 1),
#  ('years', 1),
#  ('been', 1),
#  ('dead', 1),
#  ("rec'd", 1),
#  ('call', 1),
#  ('2day', 1),
#  ('haitian', 1),
#  ('florida', 1),
#  ('15yrs', 1),
#  ('ago', 1),
#  ('preparing', 1),
#  ('acquire', 1),
#  ('bldg', 1),
#  ('suck', 1),
#  ('exhilarate', 1),
#  ('ounce', 1),
#  ('positive', 1),
#  ('psychology', 1),
#  ('shows', 1),
#  ('salespeople', 1),
#  ('88', 1),
#  ('sales', 1),
#  ('pessimism', 1),
#  ('tend', 1),
#  ('lord', 1),
#  ('christ', 1),
#  ('rest', 1),
#  ('weary', 1),
#  ('bless', 1),
#  ('dying', 1),
#  ('soothe', 1),
#  ('suffering', 1),
#  ('afflicted', 1),
#  ('shield', 1),
#  ('decision', 1),
#  ('angry', 1),
#  ('promise', 1),
#  ('wisewords', 1),
#  ('non', 1),
#  ('permissive', 1),
#  ('environment', 1),
#  ('also', 1),
#  ('battleground', 1),
#  ('milspeak', 1),
#  ('pictures', 1),
#  ('four', 1),
#  ('fictional', 1),
#  ('characters', 1),
#  ('@sunshinessp411', 1),
#  ('@israelradioguy', 1),
#  ('@wearingwelcome', 1),
#  ('@skipbaylesssux', 1),
#  ('blocking', 1),
#  ('diminish', 1),
#  ('observation', 1),
#  ('response', 1),
#  ('meanwhile', 1),
#  ('’s', 1),
#  ('knitting', 1),
#  ('sleeping', 1),
#  ('sure', 1),
#  ('certainly', 1),
#  ('n’t', 1),
#  ('@musicfae15', 1),
#  ('grumbled', 1),
#  ('sat', 1),
#  ('atop', 1),
#  ('sushi', 1),
#  ('bar', 1),
#  ('stool', 1),
#  ('crossing', 1),
#  ('arms', 1),
#  ('defiantly', 1),
#  ('gesture', 1),
#  ('gave', 1),
#  ('rachel', 1),
#  ('job', 1),
#  ('pole', 1),
#  ('5th', 1),
#  ('grade', 1),
#  ('confused', 1),
#  ('@dubai92', 1),
#  ('asking', 1),
#  ('cheeseburger', 1),
#  ('onion', 1),
#  ('mustard', 1),
#  ('mcdonalds', 1),
#  ('fee', 1),
#  ('otherwise', 1),
#  ('tricks', 1),
#  ('palm', 1),
#  ('oil', 1),
#  ('delegation', 1),
#  ('mt', 1),
#  ('resident', 1),
#  ('tzxchldaq', 1),
#  ('@thebarmyarmy', 1),
#  ('bounty', 1),
#  ('hunter', 1),
#  ('@spotted_h0rse', 1),
#  ('mirana', 1),
#  ('along', 1),
#  ('quarterback', 1),
#  ('wrecks', 1),
#  ('former', 1),
#  ('diplomat', 1),
#  ('situation', 1),
#  ('@timesnow\\nnot', 1),
#  ('stiff', 1),
#  ('upper', 1),
#  ('lip', 1),
#  ('diplomacy', 1),
#  ('seen', 1),
#  ('normally', 1),
#  ('@ryanwilson2015', 1),
#  ('compatibility', 1),
#  ('key', 1),
#  ('lowers', 1),
#  ('hedonic', 1),
#  ('volatility', 1),
#  ('god', 1),
#  ('facebook', 1),
#  ('design', 1),
#  ('remind', 1),
#  ('myspace', 1),
#  ('@engrnabeeel', 1),
#  ('lil', 1),
#  ('prematured', 1),
#  ('school', 1),
#  ('bare', 1),
#  ('legs', 1),
#  ('@jellzybean', 1),
#  ('punkin', 1),
#  ('@apkrawczynski', 1),
#  ('  ', 1),
#  ('possibly', 1),
#  ('kg', 1),
#  ('bought', 1),
#  ('player', 1),
#  ('glen', 1),
#  ('minority', 1),
#  ('owner', 1),
#  ('dreams', 1),
#  ('dashed', 1),
#  ('divided', 1),
#  ('million', 1),
#  ('stars', 1),
#  ('sky', 1),
#  ('wished', 1),
#  ('~', 1),
#  ('@educatednpetty', 1),
#  ('white', 1),
#  ('pricks', 1),
#  ('laughing', 1),
#  ('language', 1),
#  ('crying', 1),
#  ('coffin', 1),
#  ('per', 1),
#  ('popularization', 1),
#  ('backfire', 1),
#  ('cinematography', 1),
#  ('xucqb', 1),
#  ('@peachkellipop', 1),
#  ('whole', 1),
#  ('thread', 1),
#  ('fun', 1),
#  ('comment', 1),
#  ('misogyny', 1),
#  ('@nikhilv95', 1),
#  ('@lydiajanef', 1),
#  ('modicum', 1),
#  ('banter', 1),
#  ('loves', 1),
#  ('ought', 1),
#  ('place', 1),
#  ('finds', 1),
#  ('none.\\n', 1),
#  ('pastor', 1),
#  ('kris', 1),
#  ('theobald', 1),
#  ('joy', 1),
#  ('@spacekatgal', 1),
#  ('@outmagazine', 1),
#  ('okay', 1),
#  ('business', 1),
#  ('12:01', 1),
#  ('became', 1),
#  ('sentient', 1),
#  ('1.:02', 1),
#  ('posted', 1),
#  ('gn', 1),
#  ('12:03', 1),
#  ('shipped', 1),
#  ('itself', 1),
#  ('lmfao', 1),
#  ('@msnbc', 1),
#  ('racepimp', 1),
#  ('tamron', 1),
#  ('hall', 1),
#  ('words', 1),
#  ('fscts', 1),
#  ('msnbc', 1),
#  ('same', 1),
#  ('sentence', 1),
#  ('libtard', 1),
#  ('biasedmedia', 1),
#  ('neverhillary', 1),
#  ('determined', 1),
#  ('@nebulajoker', 1),
#  ('air', 1),
#  ('@iyaycruz', 1),
#  ('lets', 1),
#  ('val', 1),
#  ('far', 1),
#  ('liking', 1),
#  ('✋', 1),
#  ('🏻', 1),
#  ('rewatching', 1),
#  ('movie', 1),
#  ('late', 1),
#  ('shame', 1),
#  ('jungle', 1),
#  ('bulushi', 1),
#  ('wild', 1),
#  ('taste', 1),
#  ('@itwontcostmuch', 1),
#  ('bed', 1),
#  ('floor', 1),
#  ('curtains', 1),
#  ('hah', 1),
#  ('tried', 1),
#  ('sound', 1),
#  ("wasn't.--", 1),
#  ('@weebtard', 1),
#  ('wyd', 1),
#  ('house', 1),
#  ('longer', 1),
#  ('echoes', 1),
#  ('cold', 1),
#  ('waiting', 1),
#  ('amwriting', 1),
#  ('nostalgia', 1),
#  ('onesimplechange', 1),
#  ('instead', 1),
#  ('soft', 1),
#  ('drinks', 1),
#  ('steer', 1),
#  ('fructose', 1),
#  ('refreshing', 1),
#  ('carbonation', 1),
#  ('kick', 1),
#  ('dear', 1),
#  ('hssu', 1),
#  ('stop', 1),
#  ('walking', 1),
#  ('phones', 1),
#  ('$', 1),
#  ('srpt', 1),
#  ...]

# %%
# !pip install unidecode
from unidecode import unidecode

# !pip install Levenshtein
import Levenshtein as lev
# Out:
# Requirement already satisfied: unidecode in c:\users\felip\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: Levenshtein in c:\users\felip\anaconda3\lib\site-packages (0.18.1)
# Requirement already satisfied: rapidfuzz<3.0.0,>=2.0.1 in c:\users\felip\anaconda3\lib\site-packages (from Levenshtein) (2.0.5)

# %%
import emojilib

# %%
vowel = "aeiou"
digit = "0123456789"

def replace_multiple(string, list_replace, replace_ch):
    for ch in list_replace:
        if ch in string:
            string = string.replace(ch, replace_ch)
    return string

def sim_lev(a, b):
    return 1 - lev.distance(a, b) / max(len(a), len(b)) if len(a) != 0 else 0

# %%
tweet = df_train.iloc[123]["text"]
tweet
# Out:
# '@GroupAnon black armed thug with a record carrying gun illegally gets shot by black cop. #outrage   This is a joke.Let em destroy their town'

# %%
emo_list = emojilib.emoji_list(tweet)
emo_names = list([d['name'] for d in emo_list if 'name' in d])
emo_names
# Out:
# ['_hugging_face_', '_OK_hand_light_skin_tone_']

# %%
re.findall(r"\w+", tweet)
# Out:
# ['GroupAnon',
#  'black',
#  'armed',
#  'thug',
#  'with',
#  'a',
#  'record',
#  'carrying',
#  'gun',
#  'illegally',
#  'gets',
#  'shot',
#  'by',
#  'black',
#  'cop',
#  'outrage',
#  'This',
#  'is',
#  'a',
#  'joke',
#  'Let',
#  'em',
#  'destroy',
#  'their',
#  'town']

# %%
nlp_tweet = nlp(tweet)
for token in nlp_tweet:
    label = "text lemma pos tag dep shape is_alpha is_stop".split()
    vals = [token.text, token.lemma_.lower(), token.pos_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop]
    print(dict(zip(label[1:], vals[1:])))
# Out:
# {'lemma': '@groupanon', 'pos': 'PROPN', 'tag': 'NNP', 'dep': 'nmod', 'shape': '@XxxxxXxxx', 'is_alpha': False, 'is_stop': False}
# {'lemma': 'black', 'pos': 'ADJ', 'tag': 'JJ', 'dep': 'amod', 'shape': 'xxxx', 'is_alpha': True, 'is_stop': False}
# {'lemma': 'armed', 'pos': 'ADJ', 'tag': 'JJ', 'dep': 'amod', 'shape': 'xxxx', 'is_alpha': True, 'is_stop': False}
# {'lemma': 'thug', 'pos': 'NOUN', 'tag': 'NN', 'dep': 'nsubjpass', 'shape': 'xxxx', 'is_alpha': True, 'is_stop': False}
# {'lemma': 'with', 'pos': 'ADP', 'tag': 'IN', 'dep': 'prep', 'shape': 'xxxx', 'is_alpha': True, 'is_stop': True}
# {'lemma': 'a', 'pos': 'DET', 'tag': 'DT', 'dep': 'det', 'shape': 'x', 'is_alpha': True, 'is_stop': True}
# {'lemma': 'record', 'pos': 'NOUN', 'tag': 'NN', 'dep': 'compound', 'shape': 'xxxx', 'is_alpha': True, 'is_stop': False}
# {'lemma': 'carry', 'pos': 'VERB', 'tag': 'VBG', 'dep': 'compound', 'shape': 'xxxx', 'is_alpha': True, 'is_stop': False}
# {'lemma': 'gun', 'pos': 'NOUN', 'tag': 'NN', 'dep': 'pobj', 'shape': 'xxx', 'is_alpha': True, 'is_stop': False}
# {'lemma': 'illegally', 'pos': 'ADV', 'tag': 'RB', 'dep': 'advmod', 'shape': 'xxxx', 'is_alpha': True, 'is_stop': False}
# {'lemma': 'gets', 'pos': 'AUX', 'tag': 'VBZ', 'dep': 'auxpass', 'shape': 'xxxx', 'is_alpha': True, 'is_stop': False}
# {'lemma': 'shoot', 'pos': 'VERB', 'tag': 'VBN', 'dep': 'ROOT', 'shape': 'xxxx', 'is_alpha': True, 'is_stop': False}
# {'lemma': 'by', 'pos': 'ADP', 'tag': 'IN', 'dep': 'agent', 'shape': 'xx', 'is_alpha': True, 'is_stop': True}
# {'lemma': 'black', 'pos': 'ADJ', 'tag': 'JJ', 'dep': 'amod', 'shape': 'xxxx', 'is_alpha': True, 'is_stop': False}
# {'lemma': 'cop', 'pos': 'NOUN', 'tag': 'NN', 'dep': 'pobj', 'shape': 'xxx', 'is_alpha': True, 'is_stop': False}
# {'lemma': '.', 'pos': 'PUNCT', 'tag': '.', 'dep': 'punct', 'shape': '.', 'is_alpha': False, 'is_stop': False}
# {'lemma': '#', 'pos': 'SYM', 'tag': '$', 'dep': 'nmod', 'shape': '#', 'is_alpha': False, 'is_stop': False}
# {'lemma': 'outrage', 'pos': 'NOUN', 'tag': 'NN', 'dep': 'dep', 'shape': 'xxxx', 'is_alpha': True, 'is_stop': False}
# {'lemma': '  ', 'pos': 'SPACE', 'tag': '_SP', 'dep': 'dep', 'shape': '  ', 'is_alpha': False, 'is_stop': False}
# {'lemma': 'this', 'pos': 'PRON', 'tag': 'DT', 'dep': 'nsubj', 'shape': 'Xxxx', 'is_alpha': True, 'is_stop': True}
# {'lemma': 'be', 'pos': 'AUX', 'tag': 'VBZ', 'dep': 'ROOT', 'shape': 'xx', 'is_alpha': True, 'is_stop': True}
# {'lemma': 'a', 'pos': 'DET', 'tag': 'DT', 'dep': 'det', 'shape': 'x', 'is_alpha': True, 'is_stop': True}
# {'lemma': 'joke', 'pos': 'NOUN', 'tag': 'NN', 'dep': 'attr', 'shape': 'xxxx', 'is_alpha': True, 'is_stop': False}
# {'lemma': '.', 'pos': 'PUNCT', 'tag': '.', 'dep': 'punct', 'shape': '.', 'is_alpha': False, 'is_stop': False}
# {'lemma': 'let', 'pos': 'VERB', 'tag': 'VB', 'dep': 'ROOT', 'shape': 'Xxx', 'is_alpha': True, 'is_stop': False}
# {'lemma': 'em', 'pos': 'PRON', 'tag': 'PRP', 'dep': 'nsubj', 'shape': 'xx', 'is_alpha': True, 'is_stop': False}
# {'lemma': 'destroy', 'pos': 'VERB', 'tag': 'VB', 'dep': 'ccomp', 'shape': 'xxxx', 'is_alpha': True, 'is_stop': False}
# {'lemma': 'their', 'pos': 'PRON', 'tag': 'PRP$', 'dep': 'poss', 'shape': 'xxxx', 'is_alpha': True, 'is_stop': True}
# {'lemma': 'town', 'pos': 'NOUN', 'tag': 'NN', 'dep': 'dobj', 'shape': 'xxxx', 'is_alpha': True, 'is_stop': False}

# %%
def get_retro_attrib(tweet):
    o = {}
    o["retro<&>num_tokens"] = len(tweet.split())
    o["retro<&>lenght"] = len(" ".join(tweet.split()))
    o["retro<&>num_numbs"] = len(re.findall(r"\d+",tweet))
    o["retro<&>num_alpha"] = len(re.findall(r"\w+", tweet))
    o["retro<&>num_with_uppercase"] = len(re.findall(r"\S*[A-Z]+\S*", tweet))
    o["retro<&>num_tokens_upper"] = sum(int(t.isupper()) for t in tweet.split())
    
    def prop_vowels(w):
        N = len(w.replace(" ", ""))
        if N>0:
            return len(re.findall(r"[aeiou]", tweet)) / N
        else:
            return 0
    
    def len_max_rep_char(w):
        w=w+" "
        c0 = w[0]
        lens = [0]
        clen = 1
        for c in w[1:]:
            if c == c0:
                clen += 1
            else:
                if c0.isalpha():
                    lens.append(clen)
                c0 = c
                clen = 1
        return max(lens)  
    
    o["retro<&>prop_vowels"] = prop_vowels(tweet.lower())
    o["retro<&>len_max_rep_char"] = len_max_rep_char(tweet.lower())
    
    def max_char_fre_per_token(w, c="k"):
        tw = w.split()
        fmax = 0
        for t in tw:
            f = sum(int(ch==c) for ch in t)
            if f>fmax:
                fmax = f
        return fmax
    
    o["retro<&>max_char_fre_per_token(o)"] = max_char_fre_per_token(tweet.lower(), c="o")
    o["retro<&>max_char_fre_per_token(s)"] = max_char_fre_per_token(tweet.lower(), c="s")
    o["retro<&>max_char_fre_per_token(g)"] = max_char_fre_per_token(tweet.lower(), c="g")    
    o["retro<&>max_char_fre_per_token(l)"] = max_char_fre_per_token(tweet.lower(), c="l")    
    
    def max_type_rep_char_per_token(w, t="vowel"):
        w=unidecode(w+" ")
        c0 = w[0]
        lens = [0]
        clen = 1
        for c in w[1:]:
            if (c0.isalpha() and c.isalpha()) and ((c in "aeiou" and c0 in "aeiou") or (c not in "aeiou" and c0 not in "aeiou")):
                clen += 1
            else:
                if t=="vowel":
                    if c0 in "aeiou":
                        lens.append(clen)
                else:
                    if c0 not in "aeiou":
                        lens.append(clen) 
                c0 = c
                clen = 1
        return max(lens) 
    
    o["retro<&>max_type_rep_char_per_token(vowel)"] = max_type_rep_char_per_token(tweet.lower(), t="vowel")
    
    return o

# %%
def get_punct_attrib(tweet):
    o = {}
    o["punct<&>[\.]{3}"] = len(re.findall(r"[\.]{3}", tweet))
    o["punct<&>[!]"] = len(re.findall(r"[!]", tweet))
    o["punct<&>[#]"] = len(re.findall(r"[#]", tweet))
    o["punct<&>[#]{1}\S+"] = len(re.findall(r"[#]{1}\S+", tweet))
    o["punct<&>[\*]"] = len(re.findall(r"[\*]", tweet))
    o["punct<&>[@]{1}\S+"] = len(re.findall(r"[@]{1}\S+", tweet))
    o["punct<&>\S*[?]{1}\S*"] = len(re.findall(r"\S*[?]{1}\S*", tweet))
    return o

# %%
def get_emojilib_attrib(tweet):
    emo_list = emojilib.emoji_list(tweet)
    emo_names = list([d['name'] for d in emo_list if 'name' in d])
    o = {}
    for emo in emo_names:
        if emo not in o.keys():
            o["emoji<&>"+emo] = 0
        o["emoji<&>"+emo] += 1
    return o

# %%
def get_linguistics_attrib(tweet):
    o = {}
    nlp_tweet = nlp(tweet)
    for token in nlp_tweet:
        label = "text lemma pos tag dep shape is_alpha is_stop".split()
        vals = [token.text, token.lemma_.lower(), token.pos_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop]
        dict_vals = dict(zip(label[1:], vals[1:]))
        for k, v in dict_vals.items():
            l = f"linguistics<&>{k}<&>{v}"
            if l not in o.keys():
                o[l] = 0
            o[l] += 1
    return o

# %%
get_retro_attrib(tweet), get_punct_attrib(tweet), get_emojilib_attrib(tweet), get_linguistics_attrib(tweet)
# Out:
# ({'retro<&>num_tokens': 24,
#   'retro<&>lenght': 138,
#   'retro<&>num_numbs': 0,
#   'retro<&>num_alpha': 25,
#   'retro<&>num_with_uppercase': 3,
#   'retro<&>num_tokens_upper': 0,
#   'retro<&>prop_vowels': 0.3217391304347826,
#   'retro<&>len_max_rep_char': 2,
#   'retro<&>max_char_fre_per_token(o)': 2,
#   'retro<&>max_char_fre_per_token(s)': 1,
#   'retro<&>max_char_fre_per_token(g)': 1,
#   'retro<&>max_char_fre_per_token(l)': 4,
#   'retro<&>max_type_rep_char_per_token(vowel)': 2},
#  {'punct<&>[\\.]{3}': 0,
#   'punct<&>[!]': 0,
#   'punct<&>[#]': 1,
#   'punct<&>[#]{1}\\S+': 1,
#   'punct<&>[\\*]': 0,
#   'punct<&>[@]{1}\\S+': 1,
#   'punct<&>\\S*[?]{1}\\S*': 0},
#  {},
#  {'linguistics<&>lemma<&>@groupanon': 1,
#   'linguistics<&>pos<&>PROPN': 1,
#   'linguistics<&>tag<&>NNP': 1,
#   'linguistics<&>dep<&>nmod': 2,
#   'linguistics<&>shape<&>@XxxxxXxxx': 1,
#   'linguistics<&>is_alpha<&>False': 5,
#   'linguistics<&>is_stop<&>False': 22,
#   'linguistics<&>lemma<&>black': 2,
#   'linguistics<&>pos<&>ADJ': 3,
#   'linguistics<&>tag<&>JJ': 3,
#   'linguistics<&>dep<&>amod': 3,
#   'linguistics<&>shape<&>xxxx': 15,
#   'linguistics<&>is_alpha<&>True': 24,
#   'linguistics<&>lemma<&>armed': 1,
#   'linguistics<&>lemma<&>thug': 1,
#   'linguistics<&>pos<&>NOUN': 7,
#   'linguistics<&>tag<&>NN': 7,
#   'linguistics<&>dep<&>nsubjpass': 1,
#   'linguistics<&>lemma<&>with': 1,
#   'linguistics<&>pos<&>ADP': 2,
#   'linguistics<&>tag<&>IN': 2,
#   'linguistics<&>dep<&>prep': 1,
#   'linguistics<&>is_stop<&>True': 7,
#   'linguistics<&>lemma<&>a': 2,
#   'linguistics<&>pos<&>DET': 2,
#   'linguistics<&>tag<&>DT': 3,
#   'linguistics<&>dep<&>det': 2,
#   'linguistics<&>shape<&>x': 2,
#   'linguistics<&>lemma<&>record': 1,
#   'linguistics<&>dep<&>compound': 2,
#   'linguistics<&>lemma<&>carry': 1,
#   'linguistics<&>pos<&>VERB': 4,
#   'linguistics<&>tag<&>VBG': 1,
#   'linguistics<&>lemma<&>gun': 1,
#   'linguistics<&>dep<&>pobj': 2,
#   'linguistics<&>shape<&>xxx': 2,
#   'linguistics<&>lemma<&>illegally': 1,
#   'linguistics<&>pos<&>ADV': 1,
#   'linguistics<&>tag<&>RB': 1,
#   'linguistics<&>dep<&>advmod': 1,
#   'linguistics<&>lemma<&>gets': 1,
#   'linguistics<&>pos<&>AUX': 2,
#   'linguistics<&>tag<&>VBZ': 2,
#   'linguistics<&>dep<&>auxpass': 1,
#   'linguistics<&>lemma<&>shoot': 1,
#   'linguistics<&>tag<&>VBN': 1,
#   'linguistics<&>dep<&>ROOT': 3,
#   'linguistics<&>lemma<&>by': 1,
#   'linguistics<&>dep<&>agent': 1,
#   'linguistics<&>shape<&>xx': 3,
#   'linguistics<&>lemma<&>cop': 1,
#   'linguistics<&>lemma<&>.': 2,
#   'linguistics<&>pos<&>PUNCT': 2,
#   'linguistics<&>tag<&>.': 2,
#   'linguistics<&>dep<&>punct': 2,
#   'linguistics<&>shape<&>.': 2,
#   'linguistics<&>lemma<&>#': 1,
#   'linguistics<&>pos<&>SYM': 1,
#   'linguistics<&>tag<&>$': 1,
#   'linguistics<&>shape<&>#': 1,
#   'linguistics<&>lemma<&>outrage': 1,
#   'linguistics<&>dep<&>dep': 2,
#   'linguistics<&>lemma<&>  ': 1,
#   'linguistics<&>pos<&>SPACE': 1,
#   'linguistics<&>tag<&>_SP': 1,
#   'linguistics<&>shape<&>  ': 1,
#   'linguistics<&>lemma<&>this': 1,
#   'linguistics<&>pos<&>PRON': 3,
#   'linguistics<&>dep<&>nsubj': 2,
#   'linguistics<&>shape<&>Xxxx': 1,
#   'linguistics<&>lemma<&>be': 1,
#   'linguistics<&>lemma<&>joke': 1,
#   'linguistics<&>dep<&>attr': 1,
#   'linguistics<&>lemma<&>let': 1,
#   'linguistics<&>tag<&>VB': 2,
#   'linguistics<&>shape<&>Xxx': 1,
#   'linguistics<&>lemma<&>em': 1,
#   'linguistics<&>tag<&>PRP': 1,
#   'linguistics<&>lemma<&>destroy': 1,
#   'linguistics<&>dep<&>ccomp': 1,
#   'linguistics<&>lemma<&>their': 1,
#   'linguistics<&>tag<&>PRP$': 1,
#   'linguistics<&>dep<&>poss': 1,
#   'linguistics<&>lemma<&>town': 1,
#   'linguistics<&>dep<&>dobj': 1})

# %%
import time
import datetime

# %%
data_all_attributes = []
times = []
for k, ix in enumerate(df_train.index):
    start_time = time.time()
    tweet = df_train.loc[ix]["text"]
    o = {"id": ix}
    o = {**o, **get_retro_attrib(tweet)}
    o = {**o, **get_punct_attrib(tweet)}
    o = {**o, **get_emojilib_attrib(tweet)}
    o = {**o, **get_linguistics_attrib(tweet)}
    data_all_attributes.append(o)
    dt = time.time()-start_time
    times.append(dt)
    print(f"""
    row: {k+1}, total_rows: {df_train.shape[0]}
    progress: {np.round(100*(k+1)/df_train.shape[0], 3)}%
    wait time: {datetime.timedelta(seconds = np.mean(times)*(df_train.shape[0]-k-1))}s
    """)
# Out:
#     row: 1, total_rows: 3960
#     progress: 0.025%
#     wait time: 0:00:31.700853s
#
#
#     row: 2, total_rows: 3960
#     progress: 0.051%
#     wait time: 0:00:27.730414s
#
#
#     row: 3, total_rows: 3960
#     progress: 0.076%
#     wait time: 0:00:26.403246s
#
#
#     row: 4, total_rows: 3960
#     progress: 0.101%
#     wait time: 0:00:26.727474s
#
#
#     row: 5, total_rows: 3960
#     progress: 0.126%
#     wait time: 0:00:26.126756s
#
#
#     row: 6, total_rows: 3960
#     progress: 0.152%
#     wait time: 0:00:24.405586s
#
#
#     row: 7, total_rows: 3960
#     progress: 0.177%
#     wait time: 0:00:24.304785s
#
#
#     row: 8, total_rows: 3960
#     progress: 0.202%
#     wait time: 0:00:24.228155s
#
#
#     row: 9, total_rows: 3960
#     progress: 0.227%
#     wait time: 0:00:23.727308s
#
#
#     row: 10, total_rows: 3960
#     progress: 0.253%
#     wait time: 0:00:23.326007s
#
#
#     row: 11, total_rows: 3960
#     progress: 0.278%
#     wait time: 0:00:22.637358s
#
#
#     row: 12, total_rows: 3960
#     progress: 0.303%
#     wait time: 0:00:22.392342s
#
#
#     row: 13, total_rows: 3960
#     progress: 0.328%
#     wait time: 0:00:22.183888s
#
#
#     row: 14, total_rows: 3960
#     progress: 0.354%
#     wait time: 0:00:22.286873s
#
#
#     row: 15, total_rows: 3960
#     progress: 0.379%
#     wait time: 0:00:21.585443s
#
#
#     row: 16, total_rows: 3960
#     progress: 0.404%
#     wait time: 0:00:21.711644s
#
#
#     row: 17, total_rows: 3960
#     progress: 0.429%
#     wait time: 0:00:21.822236s
#
#
#     row: 18, total_rows: 3960
#     progress: 0.455%
#     wait time: 0:00:21.700732s
#
#
#     row: 19, total_rows: 3960
#     progress: 0.48%
#     wait time: 0:00:21.591342s
#
#
#     row: 20, total_rows: 3960
#     progress: 0.505%
#     wait time: 0:00:21.689659s
#
#
#     row: 21, total_rows: 3960
#     progress: 0.53%
#     wait time: 0:00:21.402522s
#
#
#     row: 22, total_rows: 3960
#     progress: 0.556%
#     wait time: 0:00:21.678641s
#
#
#     row: 23, total_rows: 3960
#     progress: 0.581%
#     wait time: 0:00:21.758896s
#
#
#     row: 24, total_rows: 3960
#     progress: 0.606%
#     wait time: 0:00:21.995873s
#
#
#     row: 25, total_rows: 3960
#     progress: 0.631%
#     wait time: 0:00:21.740941s
#
#
#     row: 26, total_rows: 3960
#     progress: 0.657%
#     wait time: 0:00:21.505167s
#
#
#     row: 27, total_rows: 3960
#     progress: 0.682%
#     wait time: 0:00:21.432529s
#
#
#     row: 28, total_rows: 3960
#     progress: 0.707%
#     wait time: 0:00:21.223969s
#
#
#     row: 29, total_rows: 3960
#     progress: 0.732%
#     wait time: 0:00:21.165220s
#
#
#     row: 30, total_rows: 3960
#     progress: 0.758%
#     wait time: 0:00:21.241200s
#
#
#     row: 31, total_rows: 3960
#     progress: 0.783%
#     wait time: 0:00:21.185068s
#
#
#     row: 32, total_rows: 3960
#     progress: 0.808%
#     wait time: 0:00:21.377848s
#
#
#     row: 33, total_rows: 3960
#     progress: 0.833%
#     wait time: 0:00:21.439414s
#
#
#     row: 34, total_rows: 3960
#     progress: 0.859%
#     wait time: 0:00:21.381434s
#
#
#     row: 35, total_rows: 3960
#     progress: 0.884%
#     wait time: 0:00:21.214238s
#
#
#     row: 36, total_rows: 3960
#     progress: 0.909%
#     wait time: 0:00:21.274276s
#
#
#     row: 37, total_rows: 3960
#     progress: 0.934%
#     wait time: 0:00:21.330768s
#
#
#     row: 38, total_rows: 3960
#     progress: 0.96%
#     wait time: 0:00:21.177368s
#
#
#     row: 39, total_rows: 3960
#     progress: 0.985%
#     wait time: 0:00:21.232860s
#
#
#     row: 40, total_rows: 3960
#     progress: 1.01%
#     wait time: 0:00:21.285370s
#
#
#     row: 41, total_rows: 3960
#     progress: 1.035%
#     wait time: 0:00:21.143596s
#
#
#     row: 42, total_rows: 3960
#     progress: 1.061%
#     wait time: 0:00:21.288463s
#
#
#     row: 43, total_rows: 3960
#     progress: 1.086%
#     wait time: 0:00:21.243920s
#
#
#     row: 44, total_rows: 3960
#     progress: 1.111%
#     wait time: 0:00:21.379416s
#
#
#     row: 45, total_rows: 3960
#     progress: 1.136%
#     wait time: 0:00:21.421482s
#
#
#     row: 46, total_rows: 3960
#     progress: 1.162%
#     wait time: 0:00:21.205869s
#
#
#     row: 47, total_rows: 3960
#     progress: 1.187%
#     wait time: 0:00:21.166022s
#
#
#     row: 48, total_rows: 3960
#     progress: 1.212%
#     wait time: 0:00:21.127606s
#
#
#     row: 49, total_rows: 3960
#     progress: 1.237%
#     wait time: 0:00:21.170517s
#
#
#     row: 50, total_rows: 3960
#     progress: 1.263%
#     wait time: 0:00:20.976590s
#
#
#     row: 51, total_rows: 3960
#     progress: 1.288%
#     wait time: 0:00:20.790187s
#
#
#     row: 52, total_rows: 3960
#     progress: 1.313%
#     wait time: 0:00:20.686039s
#
#
#     row: 53, total_rows: 3960
#     progress: 1.338%
#     wait time: 0:00:20.659471s
#
#
#     row: 54, total_rows: 3960
#     progress: 1.364%
#     wait time: 0:00:20.561321s
#
#
#     row: 55, total_rows: 3960
#     progress: 1.389%
#     wait time: 0:00:20.466577s
#
#
#     row: 56, total_rows: 3960
#     progress: 1.414%
#     wait time: 0:00:20.444817s
#
#
#     row: 57, total_rows: 3960
#     progress: 1.439%
#     wait time: 0:00:20.355144s
#
#
#     row: 58, total_rows: 3960
#     progress: 1.465%
#     wait time: 0:00:20.268424s
#
#
#     row: 59, total_rows: 3960
#     progress: 1.49%
#     wait time: 0:00:20.316878s
#
#
#     row: 60, total_rows: 3960
#     progress: 1.515%
#     wait time: 0:00:20.298398s
#
#
#     row: 61, total_rows: 3960
#     progress: 1.54%
#     wait time: 0:00:20.344409s
#
#
#     row: 62, total_rows: 3960
#     progress: 1.566%
#     wait time: 0:00:20.388653s
#
#
#     row: 63, total_rows: 3960
#     progress: 1.591%
#     wait time: 0:00:20.307552s
#
#
#     row: 64, total_rows: 3960
#     progress: 1.616%
#     wait time: 0:00:20.228861s
#
#
#     row: 65, total_rows: 3960
#     progress: 1.641%
#     wait time: 0:00:20.152453s
#
#
#     row: 66, total_rows: 3960
#     progress: 1.667%
#     wait time: 0:00:20.137277s
#
#
#     row: 67, total_rows: 3960
#     progress: 1.692%
#     wait time: 0:00:20.064291s
#
#
#     row: 68, total_rows: 3960
#     progress: 1.717%
#     wait time: 0:00:20.050578s
#
#
#     row: 69, total_rows: 3960
#     progress: 1.742%
#     wait time: 0:00:19.980650s
#
#
#     row: 70, total_rows: 3960
#     progress: 1.768%
#     wait time: 0:00:19.968253s
#
#
#     row: 71, total_rows: 3960
#     progress: 1.793%
#     wait time: 0:00:19.956063s
#
#
#     row: 72, total_rows: 3960
#     progress: 1.818%
#     wait time: 0:00:19.944138s
#
#
#     row: 73, total_rows: 3960
#     progress: 1.843%
#     wait time: 0:00:19.932288s
#
#
#     row: 74, total_rows: 3960
#     progress: 1.869%
#     wait time: 0:00:19.868126s
#
#
#     row: 75, total_rows: 3960
#     progress: 1.894%
#     wait time: 0:00:19.857413s
#
#
#     row: 76, total_rows: 3960
#     progress: 1.919%
#     wait time: 0:00:19.897989s
#
#
#     row: 77, total_rows: 3960
#     progress: 1.944%
#     wait time: 0:00:19.836409s
#
#
#     row: 78, total_rows: 3960
#     progress: 1.97%
#     wait time: 0:00:19.925769s
#
#
#     row: 79, total_rows: 3960
#     progress: 1.995%
#     wait time: 0:00:19.865179s
#
#
#     row: 80, total_rows: 3960
#     progress: 2.02%
#     wait time: 0:00:19.854500s
#
#
#     row: 81, total_rows: 3960
#     progress: 2.045%
#     wait time: 0:00:19.939892s
#
#
#     row: 82, total_rows: 3960
#     progress: 2.071%
#     wait time: 0:00:19.975662s
#
#
#     row: 83, total_rows: 3960
#     progress: 2.096%
#     wait time: 0:00:19.963652s
#
#
#     row: 84, total_rows: 3960
#     progress: 2.121%
#     wait time: 0:00:19.997991s
#
#
#     row: 85, total_rows: 3960
#     progress: 2.146%
#     wait time: 0:00:19.985764s
#
#
#     row: 86, total_rows: 3960
#     progress: 2.172%
#     wait time: 0:00:20.018845s
#
#
#     row: 87, total_rows: 3960
#     progress: 2.197%
#     wait time: 0:00:20.095499s
#
#
#     row: 88, total_rows: 3960
#     progress: 2.222%
#     wait time: 0:00:20.126265s
#
#
#     row: 89, total_rows: 3960
#     progress: 2.247%
#     wait time: 0:00:20.156184s
#
#
#     row: 90, total_rows: 3960
#     progress: 2.273%
#     wait time: 0:00:20.099239s
#
#
#     row: 91, total_rows: 3960
#     progress: 2.298%
#     wait time: 0:00:20.086042s
#
#
#     row: 92, total_rows: 3960
#     progress: 2.323%
#     wait time: 0:00:20.072993s
#
#
#     row: 93, total_rows: 3960
#     progress: 2.348%
#     wait time: 0:00:20.060127s
#
#
#     row: 94, total_rows: 3960
#     progress: 2.374%
#     wait time: 0:00:19.965061s
#
#
#     row: 95, total_rows: 3960
#     progress: 2.399%
#     wait time: 0:00:19.912673s
#
#
#     row: 96, total_rows: 3960
#     progress: 2.424%
#     wait time: 0:00:19.941882s
#
#
#     row: 97, total_rows: 3960
#     progress: 2.449%
#     wait time: 0:00:19.970366s
#
#
#     row: 98, total_rows: 3960
#     progress: 2.475%
#     wait time: 0:00:19.998118s
#
#
#     row: 99, total_rows: 3960
#     progress: 2.5%
#     wait time: 0:00:20.025216s
#
#
#     row: 100, total_rows: 3960
#     progress: 2.525%
#     wait time: 0:00:19.935749s
#
#
#     row: 101, total_rows: 3960
#     progress: 2.551%
#     wait time: 0:00:19.924469s
#
#
#     row: 102, total_rows: 3960
#     progress: 2.576%
#     wait time: 0:00:19.875428s
#
#
#     row: 103, total_rows: 3960
#     progress: 2.601%
#     wait time: 0:00:19.864768s
#
#
#     row: 104, total_rows: 3960
#     progress: 2.626%
#     wait time: 0:00:19.854208s
#
#
#     row: 105, total_rows: 3960
#     progress: 2.652%
#     wait time: 0:00:19.806998s
#
#
#     row: 106, total_rows: 3960
#     progress: 2.677%
#     wait time: 0:00:19.797020s
#
#
#     row: 107, total_rows: 3960
#     progress: 2.702%
#     wait time: 0:00:19.715044s
#
#
#     row: 108, total_rows: 3960
#     progress: 2.727%
#     wait time: 0:00:19.705910s
#
#
#     row: 109, total_rows: 3960
#     progress: 2.753%
#     wait time: 0:00:19.696902s
#
#
#     row: 110, total_rows: 3960
#     progress: 2.778%
#     wait time: 0:00:19.687901s
#     row: 111, total_rows: 3960
#     progress: 2.803%
#     wait time: 0:00:19.713710s
#
#
#     row: 112, total_rows: 3960
#     progress: 2.828%
#     wait time: 0:00:19.773331s
#
#
#     row: 113, total_rows: 3960
#     progress: 2.854%
#     wait time: 0:00:19.746741s
#
#
#     row: 114, total_rows: 3960
#     progress: 2.879%
#     wait time: 0:00:19.754264s
#
#
#     row: 115, total_rows: 3960
#     progress: 2.904%
#     wait time: 0:00:19.778182s
#
#
#     row: 116, total_rows: 3960
#     progress: 2.929%
#     wait time: 0:00:19.768424s
#
#
#     row: 117, total_rows: 3960
#     progress: 2.955%
#     wait time: 0:00:19.758748s
#
#
#     row: 118, total_rows: 3960
#     progress: 2.98%
#     wait time: 0:00:19.651379s
#
#
#     row: 119, total_rows: 3960
#     progress: 3.005%
#     wait time: 0:00:19.578102s
#
#
#     row: 120, total_rows: 3960
#     progress: 3.03%
#     wait time: 0:00:19.538010s
#
#
#     row: 121, total_rows: 3960
#     progress: 3.056%
#     wait time: 0:00:19.498506s
#
#
#     row: 122, total_rows: 3960
#     progress: 3.081%
#     wait time: 0:00:19.491086s
#
#
#     row: 123, total_rows: 3960
#     progress: 3.106%
#     wait time: 0:00:19.483720s
#
#
#     row: 124, total_rows: 3960
#     progress: 3.131%
#     wait time: 0:00:19.538295s
#
#
#     row: 125, total_rows: 3960
#     progress: 3.157%
#     wait time: 0:00:19.530494s
#
#
#     row: 126, total_rows: 3960
#     progress: 3.182%
#     wait time: 0:00:19.522700s
#
#
#     row: 127, total_rows: 3960
#     progress: 3.207%
#     wait time: 0:00:19.514979s
#
#
#     row: 128, total_rows: 3960
#     progress: 3.232%
#     wait time: 0:00:19.507300s
#
#
#     row: 129, total_rows: 3960
#     progress: 3.258%
#     wait time: 0:00:19.499628s
#
#
#     row: 130, total_rows: 3960
#     progress: 3.283%
#     wait time: 0:00:19.551006s
#
#
#     row: 131, total_rows: 3960
#     progress: 3.308%
#     wait time: 0:00:19.513715s
#
#
#     row: 132, total_rows: 3960
#     progress: 3.333%
#     wait time: 0:00:19.534973s
#
#
#     row: 133, total_rows: 3960
#     progress: 3.359%
#     wait time: 0:00:19.527041s
#
#
#     row: 134, total_rows: 3960
#     progress: 3.384%
#     wait time: 0:00:19.461978s
#
#
#     row: 135, total_rows: 3960
#     progress: 3.409%
#     wait time: 0:00:19.454564s
#
#
#     row: 136, total_rows: 3960
#     progress: 3.434%
#     wait time: 0:00:19.475328s
#
#
#     row: 137, total_rows: 3960
#     progress: 3.46%
#     wait time: 0:00:19.495702s
#
#
#     row: 138, total_rows: 3960
#     progress: 3.485%
#     wait time: 0:00:19.543420s
#
#
#     row: 139, total_rows: 3960
#     progress: 3.51%
#     wait time: 0:00:19.507797s
#
#
#     row: 140, total_rows: 3960
#     progress: 3.535%
#     wait time: 0:00:19.527232s
#
#
#     row: 141, total_rows: 3960
#     progress: 3.561%
#     wait time: 0:00:19.492121s
#
#
#     row: 142, total_rows: 3960
#     progress: 3.586%
#     wait time: 0:00:19.511237s
#
#
#     row: 143, total_rows: 3960
#     progress: 3.611%
#     wait time: 0:00:19.530035s
#
#
#     row: 144, total_rows: 3960
#     progress: 3.636%
#     wait time: 0:00:19.468917s
#
#
#     row: 145, total_rows: 3960
#     progress: 3.662%
#     wait time: 0:00:19.461237s
#
#
#     row: 146, total_rows: 3960
#     progress: 3.687%
#     wait time: 0:00:19.479759s
#
#
#     row: 147, total_rows: 3960
#     progress: 3.712%
#     wait time: 0:00:19.420062s
#
#
#     row: 148, total_rows: 3960
#     progress: 3.737%
#     wait time: 0:00:19.438445s
#
#
#     row: 149, total_rows: 3960
#     progress: 3.763%
#     wait time: 0:00:19.456537s
#
#
#     row: 150, total_rows: 3960
#     progress: 3.788%
#     wait time: 0:00:19.448873s
#
#
#     row: 151, total_rows: 3960
#     progress: 3.813%
#     wait time: 0:00:19.415980s
#
#
#     row: 152, total_rows: 3960
#     progress: 3.838%
#     wait time: 0:00:19.408594s
#
#
#     row: 153, total_rows: 3960
#     progress: 3.864%
#     wait time: 0:00:19.426079s
#
#
#     row: 154, total_rows: 3960
#     progress: 3.889%
#     wait time: 0:00:19.443294s
#
#
#     row: 155, total_rows: 3960
#     progress: 3.914%
#     wait time: 0:00:19.460216s
#
#
#     row: 156, total_rows: 3960
#     progress: 3.939%
#     wait time: 0:00:19.452414s
#
#
#     row: 157, total_rows: 3960
#     progress: 3.965%
#     wait time: 0:00:19.493154s
#
#
#     row: 158, total_rows: 3960
#     progress: 3.99%
#     wait time: 0:00:19.509193s
#
#
#     row: 159, total_rows: 3960
#     progress: 4.015%
#     wait time: 0:00:19.524955s
#
#
#     row: 160, total_rows: 3960
#     progress: 4.04%
#     wait time: 0:00:19.492909s
#
#
#     row: 161, total_rows: 3960
#     progress: 4.066%
#     wait time: 0:00:19.508439s
#
#
#     row: 162, total_rows: 3960
#     progress: 4.091%
#     wait time: 0:00:19.547175s
#
#
#     row: 163, total_rows: 3960
#     progress: 4.116%
#     wait time: 0:00:19.492072s
#
#
#     row: 164, total_rows: 3960
#     progress: 4.141%
#     wait time: 0:00:19.530294s
#
#
#     row: 165, total_rows: 3960
#     progress: 4.167%
#     wait time: 0:00:19.521927s
#
#
#     row: 166, total_rows: 3960
#     progress: 4.192%
#     wait time: 0:00:19.490709s
#
#
#     row: 167, total_rows: 3960
#     progress: 4.217%
#     wait time: 0:00:19.528036s
#
#
#     row: 168, total_rows: 3960
#     progress: 4.242%
#     wait time: 0:00:19.542217s
#
#
#     row: 169, total_rows: 3960
#     progress: 4.268%
#     wait time: 0:00:19.556197s
#
#
#     row: 170, total_rows: 3960
#     progress: 4.293%
#     wait time: 0:00:19.525276s
#
#
#     row: 171, total_rows: 3960
#     progress: 4.318%
#     wait time: 0:00:19.516853s
#
#
#     row: 172, total_rows: 3960
#     progress: 4.343%
#     wait time: 0:00:19.530524s
#
#
#     row: 173, total_rows: 3960
#     progress: 4.369%
#     wait time: 0:00:19.543966s
#
#
#     row: 174, total_rows: 3960
#     progress: 4.394%
#     wait time: 0:00:19.535418s
#
#
#     row: 175, total_rows: 3960
#     progress: 4.419%
#     wait time: 0:00:19.526890s
#
#
#     row: 176, total_rows: 3960
#     progress: 4.444%
#     wait time: 0:00:19.518412s
#
#
#     row: 177, total_rows: 3960
#     progress: 4.47%
#     wait time: 0:00:19.531359s
#
#
#     row: 178, total_rows: 3960
#     progress: 4.495%
#     wait time: 0:00:19.544094s
#
#
#     row: 179, total_rows: 3960
#     progress: 4.52%
#     wait time: 0:00:19.577766s
#
#
#     row: 180, total_rows: 3960
#     progress: 4.545%
#     wait time: 0:00:19.631995s
#
#
#     row: 181, total_rows: 3960
#     progress: 4.571%
#     wait time: 0:00:19.622845s
#
#
#     row: 182, total_rows: 3960
#     progress: 4.596%
#     wait time: 0:00:19.592964s
#
#
#     row: 183, total_rows: 3960
#     progress: 4.621%
#     wait time: 0:00:19.563381s
#
#
#     row: 184, total_rows: 3960
#     progress: 4.646%
#     wait time: 0:00:19.534081s
#
#
#     row: 185, total_rows: 3960
#     progress: 4.672%
#     wait time: 0:00:19.545881s
#
#
#     row: 186, total_rows: 3960
#     progress: 4.697%
#     wait time: 0:00:19.537192s
#
#
#     row: 187, total_rows: 3960
#     progress: 4.722%
#     wait time: 0:00:19.568931s
#
#
#     row: 188, total_rows: 3960
#     progress: 4.747%
#     wait time: 0:00:19.539998s
#
#
#     row: 189, total_rows: 3960
#     progress: 4.773%
#     wait time: 0:00:19.551293s
#
#
#     row: 190, total_rows: 3960
#     progress: 4.798%
#     wait time: 0:00:19.542523s
#
#
#     row: 191, total_rows: 3960
#     progress: 4.823%
#     wait time: 0:00:19.553551s
#
#
#     row: 192, total_rows: 3960
#     progress: 4.848%
#     wait time: 0:00:19.564407s
#
#
#     row: 193, total_rows: 3960
#     progress: 4.874%
#     wait time: 0:00:19.536018s
#
#
#     row: 194, total_rows: 3960
#     progress: 4.899%
#     wait time: 0:00:19.527319s
#
#
#     row: 195, total_rows: 3960
#     progress: 4.924%
#     wait time: 0:00:19.499305s
#
#
#     row: 196, total_rows: 3960
#     progress: 4.949%
#     wait time: 0:00:19.490767s
#
#
#     row: 197, total_rows: 3960
#     progress: 4.975%
#     wait time: 0:00:19.501382s
#
#
#     row: 198, total_rows: 3960
#     progress: 5.0%
#     wait time: 0:00:19.511844s
#
#
#     row: 199, total_rows: 3960
#     progress: 5.025%
#     wait time: 0:00:19.523077s
#
#
#     row: 200, total_rows: 3960
#     progress: 5.051%
#     wait time: 0:00:19.495559s
#
#
#     row: 201, total_rows: 3960
#     progress: 5.076%
#     wait time: 0:00:19.505723s
#
#
#     row: 202, total_rows: 3960
#     progress: 5.101%
#     wait time: 0:00:19.515719s
#
#
#     row: 203, total_rows: 3960
#     progress: 5.126%
#     wait time: 0:00:19.507042s
#
#
#     row: 204, total_rows: 3960
#     progress: 5.152%
#     wait time: 0:00:19.516834s
#
#
#     row: 205, total_rows: 3960
#     progress: 5.177%
#     wait time: 0:00:19.489822s
#
#
#     row: 206, total_rows: 3960
#     progress: 5.202%
#     wait time: 0:00:19.481235s
#
#
#     row: 207, total_rows: 3960
#     progress: 5.227%
#     wait time: 0:00:19.508978s
#
#
#     row: 208, total_rows: 3960
#     progress: 5.253%
#     wait time: 0:00:19.500301s
#
#
#     row: 209, total_rows: 3960
#     progress: 5.278%
#     wait time: 0:00:19.473661s
#
#
#     row: 210, total_rows: 3960
#     progress: 5.303%
#     wait time: 0:00:19.483013s
#
#
#     row: 211, total_rows: 3960
#     progress: 5.328%
#     wait time: 0:00:19.492210s
#
#
#     row: 212, total_rows: 3960
#     progress: 5.354%
#     wait time: 0:00:19.518955s
#     row: 213, total_rows: 3960
#     progress: 5.379%
#     wait time: 0:00:19.527780s
#
#
#     row: 214, total_rows: 3960
#     progress: 5.404%
#     wait time: 0:00:19.553986s
#
#
#     row: 215, total_rows: 3960
#     progress: 5.429%
#     wait time: 0:00:19.579879s
#
#
#     row: 216, total_rows: 3960
#     progress: 5.455%
#     wait time: 0:00:19.589140s
#
#
#     row: 217, total_rows: 3960
#     progress: 5.48%
#     wait time: 0:00:19.578964s
#
#
#     row: 218, total_rows: 3960
#     progress: 5.505%
#     wait time: 0:00:19.604211s
#
#
#     row: 219, total_rows: 3960
#     progress: 5.53%
#     wait time: 0:00:19.594969s
#
#
#     row: 220, total_rows: 3960
#     progress: 5.556%
#     wait time: 0:00:19.585770s
#
#
#     row: 221, total_rows: 3960
#     progress: 5.581%
#     wait time: 0:00:19.593535s
#
#
#     row: 222, total_rows: 3960
#     progress: 5.606%
#     wait time: 0:00:19.550621s
#
#
#     row: 223, total_rows: 3960
#     progress: 5.631%
#     wait time: 0:00:19.524841s
#
#
#     row: 224, total_rows: 3960
#     progress: 5.657%
#     wait time: 0:00:19.515930s
#
#
#     row: 225, total_rows: 3960
#     progress: 5.682%
#     wait time: 0:00:19.507077s
#
#
#     row: 226, total_rows: 3960
#     progress: 5.707%
#     wait time: 0:00:19.499058s
#
#
#     row: 227, total_rows: 3960
#     progress: 5.732%
#     wait time: 0:00:19.505909s
#
#
#     row: 228, total_rows: 3960
#     progress: 5.758%
#     wait time: 0:00:19.513451s
#
#
#     row: 229, total_rows: 3960
#     progress: 5.783%
#     wait time: 0:00:19.520883s
#
#
#     row: 230, total_rows: 3960
#     progress: 5.808%
#     wait time: 0:00:19.495727s
#
#
#     row: 231, total_rows: 3960
#     progress: 5.833%
#     wait time: 0:00:19.454605s
#
#
#     row: 232, total_rows: 3960
#     progress: 5.859%
#     wait time: 0:00:19.462049s
#
#
#     row: 233, total_rows: 3960
#     progress: 5.884%
#     wait time: 0:00:19.437366s
#
#
#     row: 234, total_rows: 3960
#     progress: 5.909%
#     wait time: 0:00:19.429601s
#
#
#     row: 235, total_rows: 3960
#     progress: 5.934%
#     wait time: 0:00:19.404385s
#
#
#     row: 236, total_rows: 3960
#     progress: 5.96%
#     wait time: 0:00:19.411745s
#
#
#     row: 237, total_rows: 3960
#     progress: 5.985%
#     wait time: 0:00:19.418981s
#
#
#     row: 238, total_rows: 3960
#     progress: 6.01%
#     wait time: 0:00:19.426116s
#
#
#     row: 239, total_rows: 3960
#     progress: 6.035%
#     wait time: 0:00:19.433142s
#
#
#     row: 240, total_rows: 3960
#     progress: 6.061%
#     wait time: 0:00:19.424531s
#
#
#     row: 241, total_rows: 3960
#     progress: 6.086%
#     wait time: 0:00:19.415964s
#
#
#     row: 242, total_rows: 3960
#     progress: 6.111%
#     wait time: 0:00:19.406965s
#
#
#     row: 243, total_rows: 3960
#     progress: 6.136%
#     wait time: 0:00:19.413772s
#
#
#     row: 244, total_rows: 3960
#     progress: 6.162%
#     wait time: 0:00:19.420464s
#
#
#     row: 245, total_rows: 3960
#     progress: 6.187%
#     wait time: 0:00:19.396698s
#
#
#     row: 246, total_rows: 3960
#     progress: 6.212%
#     wait time: 0:00:19.403319s
#
#
#     row: 247, total_rows: 3960
#     progress: 6.237%
#     wait time: 0:00:19.409833s
#
#
#     row: 248, total_rows: 3960
#     progress: 6.263%
#     wait time: 0:00:19.446209s
#
#
#     row: 249, total_rows: 3960
#     progress: 6.288%
#     wait time: 0:00:19.437488s
#
#
#     row: 250, total_rows: 3960
#     progress: 6.313%
#     wait time: 0:00:19.444755s
#
#
#     row: 251, total_rows: 3960
#     progress: 6.338%
#     wait time: 0:00:19.451611s
#
#
#     row: 252, total_rows: 3960
#     progress: 6.364%
#     wait time: 0:00:19.486224s
#
#
#     row: 253, total_rows: 3960
#     progress: 6.389%
#     wait time: 0:00:19.477298s
#
#
#     row: 254, total_rows: 3960
#     progress: 6.414%
#     wait time: 0:00:19.453796s
#
#
#     row: 255, total_rows: 3960
#     progress: 6.439%
#     wait time: 0:00:19.459534s
#
#
#     row: 256, total_rows: 3960
#     progress: 6.465%
#     wait time: 0:00:19.465181s
#
#
#     row: 257, total_rows: 3960
#     progress: 6.49%
#     wait time: 0:00:19.485169s
#
#
#     row: 258, total_rows: 3960
#     progress: 6.515%
#     wait time: 0:00:19.461846s
#
#
#     row: 259, total_rows: 3960
#     progress: 6.54%
#     wait time: 0:00:19.495888s
#
#
#     row: 260, total_rows: 3960
#     progress: 6.566%
#     wait time: 0:00:19.501106s
#
#
#     row: 261, total_rows: 3960
#     progress: 6.591%
#     wait time: 0:00:19.492911s
#
#
#     row: 262, total_rows: 3960
#     progress: 6.616%
#     wait time: 0:00:19.483879s
#
#
#     row: 263, total_rows: 3960
#     progress: 6.641%
#     wait time: 0:00:19.460831s
#
#
#     row: 264, total_rows: 3960
#     progress: 6.667%
#     wait time: 0:00:19.437918s
#
#
#     row: 265, total_rows: 3960
#     progress: 6.692%
#     wait time: 0:00:19.415154s
#
#
#     row: 266, total_rows: 3960
#     progress: 6.717%
#     wait time: 0:00:19.434223s
#
#
#     row: 267, total_rows: 3960
#     progress: 6.742%
#     wait time: 0:00:19.439263s
#
#
#     row: 268, total_rows: 3960
#     progress: 6.768%
#     wait time: 0:00:19.402852s
#
#
#     row: 269, total_rows: 3960
#     progress: 6.793%
#     wait time: 0:00:19.381182s
#
#
#     row: 270, total_rows: 3960
#     progress: 6.818%
#     wait time: 0:00:19.399160s
#
#
#     row: 271, total_rows: 3960
#     progress: 6.843%
#     wait time: 0:00:19.404096s
#
#
#     row: 272, total_rows: 3960
#     progress: 6.869%
#     wait time: 0:00:19.381800s
#
#
#     row: 273, total_rows: 3960
#     progress: 6.894%
#     wait time: 0:00:19.373161s
#
#
#     row: 274, total_rows: 3960
#     progress: 6.919%
#     wait time: 0:00:19.378004s
#
#
#     row: 275, total_rows: 3960
#     progress: 6.944%
#     wait time: 0:00:19.369360s
#
#
#     row: 276, total_rows: 3960
#     progress: 6.97%
#     wait time: 0:00:19.374547s
#
#
#     row: 277, total_rows: 3960
#     progress: 6.995%
#     wait time: 0:00:19.379215s
#
#
#     row: 278, total_rows: 3960
#     progress: 7.02%
#     wait time: 0:00:19.344035s
#
#
#     row: 279, total_rows: 3960
#     progress: 7.045%
#     wait time: 0:00:19.322284s
#
#
#     row: 280, total_rows: 3960
#     progress: 7.071%
#     wait time: 0:00:19.313821s
#
#
#     row: 281, total_rows: 3960
#     progress: 7.096%
#     wait time: 0:00:19.331597s
#
#
#     row: 282, total_rows: 3960
#     progress: 7.121%
#     wait time: 0:00:19.323073s
#
#
#     row: 283, total_rows: 3960
#     progress: 7.146%
#     wait time: 0:00:19.314580s
#
#
#     row: 284, total_rows: 3960
#     progress: 7.172%
#     wait time: 0:00:19.319071s
#
#
#     row: 285, total_rows: 3960
#     progress: 7.197%
#     wait time: 0:00:19.310578s
#
#
#     row: 286, total_rows: 3960
#     progress: 7.222%
#     wait time: 0:00:19.289258s
#
#
#     row: 287, total_rows: 3960
#     progress: 7.247%
#     wait time: 0:00:19.293668s
#
#
#     row: 288, total_rows: 3960
#     progress: 7.273%
#     wait time: 0:00:19.285254s
#
#
#     row: 289, total_rows: 3960
#     progress: 7.298%
#     wait time: 0:00:19.289574s
#
#
#     row: 290, total_rows: 3960
#     progress: 7.323%
#     wait time: 0:00:19.268493s
#
#
#     row: 291, total_rows: 3960
#     progress: 7.348%
#     wait time: 0:00:19.260140s
#
#
#     row: 292, total_rows: 3960
#     progress: 7.374%
#     wait time: 0:00:19.239240s
#
#
#     row: 293, total_rows: 3960
#     progress: 7.399%
#     wait time: 0:00:19.256040s
#
#
#     row: 294, total_rows: 3960
#     progress: 7.424%
#     wait time: 0:00:19.235229s
#
#
#     row: 295, total_rows: 3960
#     progress: 7.449%
#     wait time: 0:00:19.239407s
#
#
#     row: 296, total_rows: 3960
#     progress: 7.475%
#     wait time: 0:00:19.243504s
#
#
#     row: 297, total_rows: 3960
#     progress: 7.5%
#     wait time: 0:00:19.235853s
#
#
#     row: 298, total_rows: 3960
#     progress: 7.525%
#     wait time: 0:00:19.226916s
#
#
#     row: 299, total_rows: 3960
#     progress: 7.551%
#     wait time: 0:00:19.206405s
#
#
#     row: 300, total_rows: 3960
#     progress: 7.576%
#     wait time: 0:00:19.210422s
#
#
#     row: 301, total_rows: 3960
#     progress: 7.601%
#     wait time: 0:00:19.190033s
#
#
#     row: 302, total_rows: 3960
#     progress: 7.626%
#     wait time: 0:00:19.194008s
#
#
#     row: 303, total_rows: 3960
#     progress: 7.652%
#     wait time: 0:00:19.173755s
#
#
#     row: 304, total_rows: 3960
#     progress: 7.677%
#     wait time: 0:00:19.165642s
#
#
#     row: 305, total_rows: 3960
#     progress: 7.702%
#     wait time: 0:00:19.145550s
#
#
#     row: 306, total_rows: 3960
#     progress: 7.727%
#     wait time: 0:00:19.137523s
#
#
#     row: 307, total_rows: 3960
#     progress: 7.753%
#     wait time: 0:00:19.129513s
#
#
#     row: 308, total_rows: 3960
#     progress: 7.778%
#     wait time: 0:00:19.109660s
#
#
#     row: 309, total_rows: 3960
#     progress: 7.803%
#     wait time: 0:00:19.089905s
#
#
#     row: 310, total_rows: 3960
#     progress: 7.828%
#     wait time: 0:00:19.082038s
#
#
#     row: 311, total_rows: 3960
#     progress: 7.854%
#     wait time: 0:00:19.074185s
#
#
#     row: 312, total_rows: 3960
#     progress: 7.879%
#     wait time: 0:00:19.078057s
#
#
#     row: 313, total_rows: 3960
#     progress: 7.904%
#     wait time: 0:00:19.046884s
#
#
#     row: 314, total_rows: 3960
#     progress: 7.929%
#     wait time: 0:00:19.027506s
#
#
#     row: 315, total_rows: 3960
#     progress: 7.955%
#     wait time: 0:00:19.019799s
#
#
#     row: 316, total_rows: 3960
#     progress: 7.98%
#     wait time: 0:00:19.001106s
#
#
#     row: 317, total_rows: 3960
#     progress: 8.005%
#     wait time: 0:00:18.993470s
#     row: 318, total_rows: 3960
#     progress: 8.03%
#     wait time: 0:00:18.985871s
#
#
#     row: 319, total_rows: 3960
#     progress: 8.056%
#     wait time: 0:00:18.989692s
#
#
#     row: 320, total_rows: 3960
#     progress: 8.081%
#     wait time: 0:00:18.982081s
#
#
#     row: 321, total_rows: 3960
#     progress: 8.106%
#     wait time: 0:00:18.974499s
#
#
#     row: 322, total_rows: 3960
#     progress: 8.131%
#     wait time: 0:00:18.966901s
#
#
#     row: 323, total_rows: 3960
#     progress: 8.157%
#     wait time: 0:00:18.970602s
#
#
#     row: 324, total_rows: 3960
#     progress: 8.182%
#     wait time: 0:00:18.963017s
#
#
#     row: 325, total_rows: 3960
#     progress: 8.207%
#     wait time: 0:00:18.977834s
#
#
#     row: 326, total_rows: 3960
#     progress: 8.232%
#     wait time: 0:00:18.981357s
#
#
#     row: 327, total_rows: 3960
#     progress: 8.258%
#     wait time: 0:00:18.995937s
#
#
#     row: 328, total_rows: 3960
#     progress: 8.283%
#     wait time: 0:00:18.977149s
#
#
#     row: 329, total_rows: 3960
#     progress: 8.308%
#     wait time: 0:00:18.947403s
#
#
#     row: 330, total_rows: 3960
#     progress: 8.333%
#     wait time: 0:00:18.939832s
#
#
#     row: 331, total_rows: 3960
#     progress: 8.359%
#     wait time: 0:00:18.932283s
#
#
#     row: 332, total_rows: 3960
#     progress: 8.384%
#     wait time: 0:00:18.913801s
#
#
#     row: 333, total_rows: 3960
#     progress: 8.409%
#     wait time: 0:00:18.895813s
#
#
#     row: 334, total_rows: 3960
#     progress: 8.434%
#     wait time: 0:00:18.909713s
#
#
#     row: 335, total_rows: 3960
#     progress: 8.46%
#     wait time: 0:00:18.913049s
#
#
#     row: 336, total_rows: 3960
#     progress: 8.485%
#     wait time: 0:00:18.894739s
#
#
#     row: 337, total_rows: 3960
#     progress: 8.51%
#     wait time: 0:00:18.887272s
#
#
#     row: 338, total_rows: 3960
#     progress: 8.535%
#     wait time: 0:00:18.890560s
#
#
#     row: 339, total_rows: 3960
#     progress: 8.561%
#     wait time: 0:00:18.893775s
#
#
#     row: 340, total_rows: 3960
#     progress: 8.586%
#     wait time: 0:00:18.897485s
#
#
#     row: 341, total_rows: 3960
#     progress: 8.611%
#     wait time: 0:00:18.889432s
#
#
#     row: 342, total_rows: 3960
#     progress: 8.636%
#     wait time: 0:00:18.882479s
#
#
#     row: 343, total_rows: 3960
#     progress: 8.662%
#     wait time: 0:00:18.863909s
#
#
#     row: 344, total_rows: 3960
#     progress: 8.687%
#     wait time: 0:00:18.867531s
#
#
#     row: 345, total_rows: 3960
#     progress: 8.712%
#     wait time: 0:00:18.839102s
#
#
#     row: 346, total_rows: 3960
#     progress: 8.737%
#     wait time: 0:00:18.832367s
#
#
#     row: 347, total_rows: 3960
#     progress: 8.763%
#     wait time: 0:00:18.824360s
#
#
#     row: 348, total_rows: 3960
#     progress: 8.788%
#     wait time: 0:00:18.796237s
#
#
#     row: 349, total_rows: 3960
#     progress: 8.813%
#     wait time: 0:00:18.778614s
#
#
#     row: 350, total_rows: 3960
#     progress: 8.838%
#     wait time: 0:00:18.771397s
#
#
#     row: 351, total_rows: 3960
#     progress: 8.864%
#     wait time: 0:00:18.764190s
#
#
#     row: 352, total_rows: 3960
#     progress: 8.889%
#     wait time: 0:00:18.757001s
#
#
#     row: 353, total_rows: 3960
#     progress: 8.914%
#     wait time: 0:00:18.749824s
#
#
#     row: 354, total_rows: 3960
#     progress: 8.939%
#     wait time: 0:00:18.742635s
#
#
#     row: 355, total_rows: 3960
#     progress: 8.965%
#     wait time: 0:00:18.725316s
#
#
#     row: 356, total_rows: 3960
#     progress: 8.99%
#     wait time: 0:00:18.708069s
#
#
#     row: 357, total_rows: 3960
#     progress: 9.015%
#     wait time: 0:00:18.700999s
#
#
#     row: 358, total_rows: 3960
#     progress: 9.04%
#     wait time: 0:00:18.714087s
#
#
#     row: 359, total_rows: 3960
#     progress: 9.066%
#     wait time: 0:00:18.706970s
#
#
#     row: 360, total_rows: 3960
#     progress: 9.091%
#     wait time: 0:00:18.710444s
#
#
#     row: 361, total_rows: 3960
#     progress: 9.116%
#     wait time: 0:00:18.712740s
#
#
#     row: 362, total_rows: 3960
#     progress: 9.141%
#     wait time: 0:00:18.705605s
#
#
#     row: 363, total_rows: 3960
#     progress: 9.167%
#     wait time: 0:00:18.698486s
#
#
#     row: 364, total_rows: 3960
#     progress: 9.192%
#     wait time: 0:00:18.701255s
#
#
#     row: 365, total_rows: 3960
#     progress: 9.217%
#     wait time: 0:00:18.703980s
#
#
#     row: 366, total_rows: 3960
#     progress: 9.242%
#     wait time: 0:00:18.677177s
#
#
#     row: 367, total_rows: 3960
#     progress: 9.268%
#     wait time: 0:00:18.670097s
#
#
#     row: 368, total_rows: 3960
#     progress: 9.293%
#     wait time: 0:00:18.682572s
#
#
#     row: 369, total_rows: 3960
#     progress: 9.318%
#     wait time: 0:00:18.665714s
#
#
#     row: 370, total_rows: 3960
#     progress: 9.343%
#     wait time: 0:00:18.648929s
#
#
#     row: 371, total_rows: 3960
#     progress: 9.369%
#     wait time: 0:00:18.641894s
#
#
#     row: 372, total_rows: 3960
#     progress: 9.394%
#     wait time: 0:00:18.644521s
#
#
#     row: 373, total_rows: 3960
#     progress: 9.419%
#     wait time: 0:00:18.656745s
#
#
#     row: 374, total_rows: 3960
#     progress: 9.444%
#     wait time: 0:00:18.659242s
#
#
#     row: 375, total_rows: 3960
#     progress: 9.47%
#     wait time: 0:00:18.661707s
#
#
#     row: 376, total_rows: 3960
#     progress: 9.495%
#     wait time: 0:00:18.659594s
#
#
#     row: 377, total_rows: 3960
#     progress: 9.52%
#     wait time: 0:00:18.642949s
#
#
#     row: 378, total_rows: 3960
#     progress: 9.545%
#     wait time: 0:00:18.635867s
#
#
#     row: 379, total_rows: 3960
#     progress: 9.571%
#     wait time: 0:00:18.619778s
#
#
#     row: 380, total_rows: 3960
#     progress: 9.596%
#     wait time: 0:00:18.612744s
#
#
#     row: 381, total_rows: 3960
#     progress: 9.621%
#     wait time: 0:00:18.615120s
#
#
#     row: 382, total_rows: 3960
#     progress: 9.646%
#     wait time: 0:00:18.589328s
#
#
#     row: 383, total_rows: 3960
#     progress: 9.672%
#     wait time: 0:00:18.573473s
#
#
#     row: 384, total_rows: 3960
#     progress: 9.697%
#     wait time: 0:00:18.575381s
#
#
#     row: 385, total_rows: 3960
#     progress: 9.722%
#     wait time: 0:00:18.577709s
#
#
#     row: 386, total_rows: 3960
#     progress: 9.747%
#     wait time: 0:00:18.561466s
#
#
#     row: 387, total_rows: 3960
#     progress: 9.773%
#     wait time: 0:00:18.554536s
#
#
#     row: 388, total_rows: 3960
#     progress: 9.798%
#     wait time: 0:00:18.547607s
#
#
#     row: 389, total_rows: 3960
#     progress: 9.823%
#     wait time: 0:00:18.549880s
#
#
#     row: 390, total_rows: 3960
#     progress: 9.848%
#     wait time: 0:00:18.542947s
#
#
#     row: 391, total_rows: 3960
#     progress: 9.874%
#     wait time: 0:00:18.536028s
#
#
#     row: 392, total_rows: 3960
#     progress: 9.899%
#     wait time: 0:00:18.529570s
#
#
#     row: 393, total_rows: 3960
#     progress: 9.924%
#     wait time: 0:00:18.522202s
#
#
#     row: 394, total_rows: 3960
#     progress: 9.949%
#     wait time: 0:00:18.524366s
#
#
#     row: 395, total_rows: 3960
#     progress: 9.975%
#     wait time: 0:00:18.526489s
#
#
#     row: 396, total_rows: 3960
#     progress: 10.0%
#     wait time: 0:00:18.519561s
#
#
#     row: 397, total_rows: 3960
#     progress: 10.025%
#     wait time: 0:00:18.521628s
#
#
#     row: 398, total_rows: 3960
#     progress: 10.051%
#     wait time: 0:00:18.514694s
#
#
#     row: 399, total_rows: 3960
#     progress: 10.076%
#     wait time: 0:00:18.498850s
#
#
#     row: 400, total_rows: 3960
#     progress: 10.101%
#     wait time: 0:00:18.483054s
#
#
#     row: 401, total_rows: 3960
#     progress: 10.126%
#     wait time: 0:00:18.485084s
#
#
#     row: 402, total_rows: 3960
#     progress: 10.152%
#     wait time: 0:00:18.478211s
#
#
#     row: 403, total_rows: 3960
#     progress: 10.177%
#     wait time: 0:00:18.462519s
#
#
#     row: 404, total_rows: 3960
#     progress: 10.202%
#     wait time: 0:00:18.473308s
#
#
#     row: 405, total_rows: 3960
#     progress: 10.227%
#     wait time: 0:00:18.475232s
#
#
#     row: 406, total_rows: 3960
#     progress: 10.253%
#     wait time: 0:00:18.459590s
#
#
#     row: 407, total_rows: 3960
#     progress: 10.278%
#     wait time: 0:00:18.452747s
#
#
#     row: 408, total_rows: 3960
#     progress: 10.303%
#     wait time: 0:00:18.445900s
#
#
#     row: 409, total_rows: 3960
#     progress: 10.328%
#     wait time: 0:00:18.421694s
#
#
#     row: 410, total_rows: 3960
#     progress: 10.354%
#     wait time: 0:00:18.397582s
#
#
#     row: 411, total_rows: 3960
#     progress: 10.379%
#     wait time: 0:00:18.390868s
#
#
#     row: 412, total_rows: 3960
#     progress: 10.404%
#     wait time: 0:00:18.384159s
#
#
#     row: 413, total_rows: 3960
#     progress: 10.429%
#     wait time: 0:00:18.360271s
#
#
#     row: 414, total_rows: 3960
#     progress: 10.455%
#     wait time: 0:00:18.336477s
#
#
#     row: 415, total_rows: 3960
#     progress: 10.48%
#     wait time: 0:00:18.329882s
#
#
#     row: 416, total_rows: 3960
#     progress: 10.505%
#     wait time: 0:00:18.306242s
#
#
#     row: 417, total_rows: 3960
#     progress: 10.53%
#     wait time: 0:00:18.291209s
#
#
#     row: 418, total_rows: 3960
#     progress: 10.556%
#     wait time: 0:00:18.276224s
#
#
#     row: 419, total_rows: 3960
#     progress: 10.581%
#     wait time: 0:00:18.261292s
#
#
#     row: 420, total_rows: 3960
#     progress: 10.606%
#     wait time: 0:00:18.263286s
#
#
#     row: 421, total_rows: 3960
#     progress: 10.631%
#     wait time: 0:00:18.265246s
#
#
#     row: 422, total_rows: 3960
#     progress: 10.657%
#     wait time: 0:00:18.250376s
#
#
#     row: 423, total_rows: 3960
#     progress: 10.682%
#     wait time: 0:00:18.227191s
#
#
#     row: 424, total_rows: 3960
#     progress: 10.707%
#     wait time: 0:00:18.229145s
#
#
#     row: 425, total_rows: 3960
#     progress: 10.732%
#     wait time: 0:00:18.214410s
#
#
#     row: 426, total_rows: 3960
#     progress: 10.758%
#     wait time: 0:00:18.199725s
#
#
#     row: 427, total_rows: 3960
#     progress: 10.783%
#     wait time: 0:00:18.185090s
#     row: 428, total_rows: 3960
#     progress: 10.808%
#     wait time: 0:00:18.162245s
#
#
#     row: 429, total_rows: 3960
#     progress: 10.833%
#     wait time: 0:00:18.164211s
#
#
#     row: 430, total_rows: 3960
#     progress: 10.859%
#     wait time: 0:00:18.157921s
#
#
#     row: 431, total_rows: 3960
#     progress: 10.884%
#     wait time: 0:00:18.143440s
#
#
#     row: 432, total_rows: 3960
#     progress: 10.909%
#     wait time: 0:00:18.153529s
#
#
#     row: 433, total_rows: 3960
#     progress: 10.934%
#     wait time: 0:00:18.155388s
#
#
#     row: 434, total_rows: 3960
#     progress: 10.96%
#     wait time: 0:00:18.149082s
#
#
#     row: 435, total_rows: 3960
#     progress: 10.985%
#     wait time: 0:00:18.134666s
#
#
#     row: 436, total_rows: 3960
#     progress: 11.01%
#     wait time: 0:00:18.144566s
#
#
#     row: 437, total_rows: 3960
#     progress: 11.035%
#     wait time: 0:00:18.146326s
#
#
#     row: 438, total_rows: 3960
#     progress: 11.061%
#     wait time: 0:00:18.139999s
#
#
#     row: 439, total_rows: 3960
#     progress: 11.086%
#     wait time: 0:00:18.133670s
#
#
#     row: 440, total_rows: 3960
#     progress: 11.111%
#     wait time: 0:00:18.143373s
#
#
#     row: 441, total_rows: 3960
#     progress: 11.136%
#     wait time: 0:00:18.145009s
#
#
#     row: 442, total_rows: 3960
#     progress: 11.162%
#     wait time: 0:00:18.130678s
#
#
#     row: 443, total_rows: 3960
#     progress: 11.187%
#     wait time: 0:00:18.140235s
#
#
#     row: 444, total_rows: 3960
#     progress: 11.212%
#     wait time: 0:00:18.141789s
#
#
#     row: 445, total_rows: 3960
#     progress: 11.237%
#     wait time: 0:00:18.135402s
#
#
#     row: 446, total_rows: 3960
#     progress: 11.263%
#     wait time: 0:00:18.129023s
#
#
#     row: 447, total_rows: 3960
#     progress: 11.288%
#     wait time: 0:00:18.122647s
#
#
#     row: 448, total_rows: 3960
#     progress: 11.313%
#     wait time: 0:00:18.124120s
#
#
#     row: 449, total_rows: 3960
#     progress: 11.338%
#     wait time: 0:00:18.125567s
#
#
#     row: 450, total_rows: 3960
#     progress: 11.364%
#     wait time: 0:00:18.126978s
#
#
#     row: 451, total_rows: 3960
#     progress: 11.389%
#     wait time: 0:00:18.128362s
#
#
#     row: 452, total_rows: 3960
#     progress: 11.414%
#     wait time: 0:00:18.121941s
#
#
#     row: 453, total_rows: 3960
#     progress: 11.439%
#     wait time: 0:00:18.131019s
#
#
#     row: 454, total_rows: 3960
#     progress: 11.465%
#     wait time: 0:00:18.132303s
#
#
#     row: 455, total_rows: 3960
#     progress: 11.49%
#     wait time: 0:00:18.133546s
#
#
#     row: 456, total_rows: 3960
#     progress: 11.515%
#     wait time: 0:00:18.134778s
#
#
#     row: 457, total_rows: 3960
#     progress: 11.54%
#     wait time: 0:00:18.135956s
#
#
#     row: 458, total_rows: 3960
#     progress: 11.566%
#     wait time: 0:00:18.121806s
#
#
#     row: 459, total_rows: 3960
#     progress: 11.591%
#     wait time: 0:00:18.115334s
#
#
#     row: 460, total_rows: 3960
#     progress: 11.616%
#     wait time: 0:00:18.116481s
#
#
#     row: 461, total_rows: 3960
#     progress: 11.641%
#     wait time: 0:00:18.110014s
#
#
#     row: 462, total_rows: 3960
#     progress: 11.667%
#     wait time: 0:00:18.118691s
#
#
#     row: 463, total_rows: 3960
#     progress: 11.692%
#     wait time: 0:00:18.119749s
#
#
#     row: 464, total_rows: 3960
#     progress: 11.717%
#     wait time: 0:00:18.105695s
#
#
#     row: 465, total_rows: 3960
#     progress: 11.742%
#     wait time: 0:00:18.091683s
#
#
#     row: 466, total_rows: 3960
#     progress: 11.768%
#     wait time: 0:00:18.092728s
#
#
#     row: 467, total_rows: 3960
#     progress: 11.793%
#     wait time: 0:00:18.093736s
#
#
#     row: 468, total_rows: 3960
#     progress: 11.818%
#     wait time: 0:00:18.094711s
#
#
#     row: 469, total_rows: 3960
#     progress: 11.843%
#     wait time: 0:00:18.080755s
#
#
#     row: 470, total_rows: 3960
#     progress: 11.869%
#     wait time: 0:00:18.074278s
#
#
#     row: 471, total_rows: 3960
#     progress: 11.894%
#     wait time: 0:00:18.075228s
#
#
#     row: 472, total_rows: 3960
#     progress: 11.919%
#     wait time: 0:00:18.068745s
#
#
#     row: 473, total_rows: 3960
#     progress: 11.944%
#     wait time: 0:00:18.069645s
#
#
#     row: 474, total_rows: 3960
#     progress: 11.97%
#     wait time: 0:00:18.063153s
#
#
#     row: 475, total_rows: 3960
#     progress: 11.995%
#     wait time: 0:00:18.056675s
#
#
#     row: 476, total_rows: 3960
#     progress: 12.02%
#     wait time: 0:00:18.057525s
#
#
#     row: 477, total_rows: 3960
#     progress: 12.045%
#     wait time: 0:00:18.051047s
#
#
#     row: 478, total_rows: 3960
#     progress: 12.071%
#     wait time: 0:00:18.044564s
#
#
#     row: 479, total_rows: 3960
#     progress: 12.096%
#     wait time: 0:00:18.045358s
#
#
#     row: 480, total_rows: 3960
#     progress: 12.121%
#     wait time: 0:00:18.031616s
#
#
#     row: 481, total_rows: 3960
#     progress: 12.146%
#     wait time: 0:00:18.039642s
#
#
#     row: 482, total_rows: 3960
#     progress: 12.172%
#     wait time: 0:00:18.040376s
#
#
#     row: 483, total_rows: 3960
#     progress: 12.197%
#     wait time: 0:00:18.041084s
#
#
#     row: 484, total_rows: 3960
#     progress: 12.222%
#     wait time: 0:00:18.034574s
#
#
#     row: 485, total_rows: 3960
#     progress: 12.247%
#     wait time: 0:00:18.042407s
#
#
#     row: 486, total_rows: 3960
#     progress: 12.273%
#     wait time: 0:00:18.043031s
#
#
#     row: 487, total_rows: 3960
#     progress: 12.298%
#     wait time: 0:00:18.043624s
#
#
#     row: 488, total_rows: 3960
#     progress: 12.323%
#     wait time: 0:00:18.044192s
#
#
#     row: 489, total_rows: 3960
#     progress: 12.348%
#     wait time: 0:00:18.030525s
#
#
#     row: 490, total_rows: 3960
#     progress: 12.374%
#     wait time: 0:00:18.023985s
#
#
#     row: 491, total_rows: 3960
#     progress: 12.399%
#     wait time: 0:00:18.024521s
#
#
#     row: 492, total_rows: 3960
#     progress: 12.424%
#     wait time: 0:00:18.010922s
#
#
#     row: 493, total_rows: 3960
#     progress: 12.449%
#     wait time: 0:00:18.011438s
#
#
#     row: 494, total_rows: 3960
#     progress: 12.475%
#     wait time: 0:00:18.004903s
#
#
#     row: 495, total_rows: 3960
#     progress: 12.5%
#     wait time: 0:00:17.998383s
#
#
#     row: 496, total_rows: 3960
#     progress: 12.525%
#     wait time: 0:00:17.991860s
#
#
#     row: 497, total_rows: 3960
#     progress: 12.551%
#     wait time: 0:00:17.999295s
#
#
#     row: 498, total_rows: 3960
#     progress: 12.576%
#     wait time: 0:00:17.999712s
#
#
#     row: 499, total_rows: 3960
#     progress: 12.601%
#     wait time: 0:00:17.993167s
#
#
#     row: 500, total_rows: 3960
#     progress: 12.626%
#     wait time: 0:00:17.993545s
#
#
#     row: 501, total_rows: 3960
#     progress: 12.652%
#     wait time: 0:00:17.993902s
#
#
#     row: 502, total_rows: 3960
#     progress: 12.677%
#     wait time: 0:00:17.994236s
#
#
#     row: 503, total_rows: 3960
#     progress: 12.702%
#     wait time: 0:00:17.980781s
#
#
#     row: 504, total_rows: 3960
#     progress: 12.727%
#     wait time: 0:00:17.981094s
#
#
#     row: 505, total_rows: 3960
#     progress: 12.753%
#     wait time: 0:00:17.974529s
#
#
#     row: 506, total_rows: 3960
#     progress: 12.778%
#     wait time: 0:00:17.967978s
#
#
#     row: 507, total_rows: 3960
#     progress: 12.803%
#     wait time: 0:00:17.961433s
#
#
#     row: 508, total_rows: 3960
#     progress: 12.828%
#     wait time: 0:00:17.954893s
#
#
#     row: 509, total_rows: 3960
#     progress: 12.854%
#     wait time: 0:00:17.941573s
#
#
#     row: 510, total_rows: 3960
#     progress: 12.879%
#     wait time: 0:00:17.935061s
#
#
#     row: 511, total_rows: 3960
#     progress: 12.904%
#     wait time: 0:00:17.935304s
#
#
#     row: 512, total_rows: 3960
#     progress: 12.929%
#     wait time: 0:00:17.928794s
#
#
#     row: 513, total_rows: 3960
#     progress: 12.955%
#     wait time: 0:00:17.929004s
#
#
#     row: 514, total_rows: 3960
#     progress: 12.98%
#     wait time: 0:00:17.929192s
#
#
#     row: 515, total_rows: 3960
#     progress: 13.005%
#     wait time: 0:00:17.929357s
#
#
#     row: 516, total_rows: 3960
#     progress: 13.03%
#     wait time: 0:00:17.916138s
#
#
#     row: 517, total_rows: 3960
#     progress: 13.056%
#     wait time: 0:00:17.916290s
#
#
#     row: 518, total_rows: 3960
#     progress: 13.081%
#     wait time: 0:00:17.909759s
#
#
#     row: 519, total_rows: 3960
#     progress: 13.106%
#     wait time: 0:00:17.903237s
#
#
#     row: 520, total_rows: 3960
#     progress: 13.131%
#     wait time: 0:00:17.883475s
#
#
#     row: 521, total_rows: 3960
#     progress: 13.157%
#     wait time: 0:00:17.870387s
#
#
#     row: 522, total_rows: 3960
#     progress: 13.182%
#     wait time: 0:00:17.863925s
#
#
#     row: 523, total_rows: 3960
#     progress: 13.207%
#     wait time: 0:00:17.857474s
#
#
#     row: 524, total_rows: 3960
#     progress: 13.232%
#     wait time: 0:00:17.844461s
#
#
#     row: 525, total_rows: 3960
#     progress: 13.258%
#     wait time: 0:00:17.844587s
#
#
#     row: 526, total_rows: 3960
#     progress: 13.283%
#     wait time: 0:00:17.838145s
#
#
#     row: 527, total_rows: 3960
#     progress: 13.308%
#     wait time: 0:00:17.831710s
#
#
#     row: 528, total_rows: 3960
#     progress: 13.333%
#     wait time: 0:00:17.825283s
#
#
#     row: 529, total_rows: 3960
#     progress: 13.359%
#     wait time: 0:00:17.812371s
#     row: 530, total_rows: 3960
#     progress: 13.384%
#     wait time: 0:00:17.812442s
#
#
#     row: 531, total_rows: 3960
#     progress: 13.409%
#     wait time: 0:00:17.812500s
#
#
#     row: 532, total_rows: 3960
#     progress: 13.434%
#     wait time: 0:00:17.799633s
#
#
#     row: 533, total_rows: 3960
#     progress: 13.46%
#     wait time: 0:00:17.793232s
#
#
#     row: 534, total_rows: 3960
#     progress: 13.485%
#     wait time: 0:00:17.793254s
#
#
#     row: 535, total_rows: 3960
#     progress: 13.51%
#     wait time: 0:00:17.786849s
#
#
#     row: 536, total_rows: 3960
#     progress: 13.535%
#     wait time: 0:00:17.793238s
#
#
#     row: 537, total_rows: 3960
#     progress: 13.561%
#     wait time: 0:00:17.786818s
#
#
#     row: 538, total_rows: 3960
#     progress: 13.586%
#     wait time: 0:00:17.786769s
#
#
#     row: 539, total_rows: 3960
#     progress: 13.611%
#     wait time: 0:00:17.780346s
#
#
#     row: 540, total_rows: 3960
#     progress: 13.636%
# ...
#
#
#     row: 3785, total_rows: 3960
#     progress: 95.581%
#     wait time: 0:00:00.946900s
#
#
#     row: 3786, total_rows: 3960
#     progress: 95.606%
#     wait time: 0:00:00.941516s
#
#
#     row: 3787, total_rows: 3960
#     progress: 95.631%
#     wait time: 0:00:00.936086s
#
#
#     row: 3788, total_rows: 3960
#     progress: 95.657%
#     wait time: 0:00:00.930703s
#
#
#     row: 3789, total_rows: 3960
#     progress: 95.682%
#     wait time: 0:00:00.925273s
#
#
#     row: 3790, total_rows: 3960
#     progress: 95.707%
#     wait time: 0:00:00.919844s
#
#
#     row: 3791, total_rows: 3960
#     progress: 95.732%
#     wait time: 0:00:00.914415s
#
#
#     row: 3792, total_rows: 3960
#     progress: 95.758%
#     wait time: 0:00:00.908986s
#
#
#     row: 3793, total_rows: 3960
#     progress: 95.783%
#     wait time: 0:00:00.903602s
#
#
#     row: 3794, total_rows: 3960
#     progress: 95.808%
#     wait time: 0:00:00.898173s
#
#
#     row: 3795, total_rows: 3960
#     progress: 95.833%
#     wait time: 0:00:00.892788s
#
#
#     row: 3796, total_rows: 3960
#     progress: 95.859%
#     wait time: 0:00:00.887274s
#
#
#     row: 3797, total_rows: 3960
#     progress: 95.884%
#     wait time: 0:00:00.881889s
#
#
#     row: 3798, total_rows: 3960
#     progress: 95.909%
#     wait time: 0:00:00.876504s
#
#
#     row: 3799, total_rows: 3960
#     progress: 95.934%
#     wait time: 0:00:00.871161s
#
#
#     row: 3800, total_rows: 3960
#     progress: 95.96%
#     wait time: 0:00:00.865817s
#
#
#     row: 3801, total_rows: 3960
#     progress: 95.985%
#     wait time: 0:00:00.860431s
#
#
#     row: 3802, total_rows: 3960
#     progress: 96.01%
#     wait time: 0:00:00.854919s
#
#
#     row: 3803, total_rows: 3960
#     progress: 96.035%
#     wait time: 0:00:00.849533s
#
#
#     row: 3804, total_rows: 3960
#     progress: 96.061%
#     wait time: 0:00:00.844105s
#
#
#     row: 3805, total_rows: 3960
#     progress: 96.086%
#     wait time: 0:00:00.838678s
#
#
#     row: 3806, total_rows: 3960
#     progress: 96.111%
#     wait time: 0:00:00.833291s
#
#
#     row: 3807, total_rows: 3960
#     progress: 96.136%
#     wait time: 0:00:00.827984s
#
#
#     row: 3808, total_rows: 3960
#     progress: 96.162%
#     wait time: 0:00:00.822556s
#
#
#     row: 3809, total_rows: 3960
#     progress: 96.187%
#     wait time: 0:00:00.817129s
#
#
#     row: 3810, total_rows: 3960
#     progress: 96.212%
#     wait time: 0:00:00.811741s
#
#
#     row: 3811, total_rows: 3960
#     progress: 96.237%
#     wait time: 0:00:00.806352s
#
#
#     row: 3812, total_rows: 3960
#     progress: 96.263%
#     wait time: 0:00:00.800964s
#
#
#     row: 3813, total_rows: 3960
#     progress: 96.288%
#     wait time: 0:00:00.795613s
#
#
#     row: 3814, total_rows: 3960
#     progress: 96.313%
#     wait time: 0:00:00.790262s
#
#
#     row: 3815, total_rows: 3960
#     progress: 96.338%
#     wait time: 0:00:00.784910s
#
#
#     row: 3816, total_rows: 3960
#     progress: 96.364%
#     wait time: 0:00:00.779481s
#
#
#     row: 3817, total_rows: 3960
#     progress: 96.389%
#     wait time: 0:00:00.774128s
#
#
#     row: 3818, total_rows: 3960
#     progress: 96.414%
#     wait time: 0:00:00.768736s
#
#
#     row: 3819, total_rows: 3960
#     progress: 96.439%
#     wait time: 0:00:00.763419s
#
#
#     row: 3820, total_rows: 3960
#     progress: 96.465%
#     wait time: 0:00:00.758026s
#
#
#     row: 3821, total_rows: 3960
#     progress: 96.49%
#     wait time: 0:00:00.752560s
#
#
#     row: 3822, total_rows: 3960
#     progress: 96.515%
#     wait time: 0:00:00.747095s
#
#
#     row: 3823, total_rows: 3960
#     progress: 96.54%
#     wait time: 0:00:00.741738s
#
#
#     row: 3824, total_rows: 3960
#     progress: 96.566%
#     wait time: 0:00:00.736310s
#
#
#     row: 3825, total_rows: 3960
#     progress: 96.591%
#     wait time: 0:00:00.730881s
#
#
#     row: 3826, total_rows: 3960
#     progress: 96.616%
#     wait time: 0:00:00.725488s
#
#
#     row: 3827, total_rows: 3960
#     progress: 96.641%
#     wait time: 0:00:00.720095s
#
#
#     row: 3828, total_rows: 3960
#     progress: 96.667%
#     wait time: 0:00:00.714666s
#
#
#     row: 3829, total_rows: 3960
#     progress: 96.692%
#     wait time: 0:00:00.709204s
#
#
#     row: 3830, total_rows: 3960
#     progress: 96.717%
#     wait time: 0:00:00.703878s
#
#
#     row: 3831, total_rows: 3960
#     progress: 96.742%
#     wait time: 0:00:00.698517s
#
#
#     row: 3832, total_rows: 3960
#     progress: 96.768%
#     wait time: 0:00:00.693055s
#
#
#     row: 3833, total_rows: 3960
#     progress: 96.793%
#     wait time: 0:00:00.687594s
#
#
#     row: 3834, total_rows: 3960
#     progress: 96.818%
#     wait time: 0:00:00.682166s
#
#
#     row: 3835, total_rows: 3960
#     progress: 96.843%
#     wait time: 0:00:00.676772s
#
#
#     row: 3836, total_rows: 3960
#     progress: 96.869%
#     wait time: 0:00:00.671409s
#
#
#     row: 3837, total_rows: 3960
#     progress: 96.894%
#     wait time: 0:00:00.665981s
#
#
#     row: 3838, total_rows: 3960
#     progress: 96.919%
#     wait time: 0:00:00.660585s
#
#
#     row: 3839, total_rows: 3960
#     progress: 96.944%
#     wait time: 0:00:00.655189s
#
#
#     row: 3840, total_rows: 3960
#     progress: 96.97%
#     wait time: 0:00:00.649762s
#
#
#     row: 3841, total_rows: 3960
#     progress: 96.995%
#     wait time: 0:00:00.644303s
#
#
#     row: 3842, total_rows: 3960
#     progress: 97.02%
#     wait time: 0:00:00.638907s
#
#
#     row: 3843, total_rows: 3960
#     progress: 97.045%
#     wait time: 0:00:00.633450s
#
#
#     row: 3844, total_rows: 3960
#     progress: 97.071%
#     wait time: 0:00:00.628054s
#
#
#     row: 3845, total_rows: 3960
#     progress: 97.096%
#     wait time: 0:00:00.622597s
#
#
#     row: 3846, total_rows: 3960
#     progress: 97.121%
#     wait time: 0:00:00.617201s
#     row: 3847, total_rows: 3960
#     progress: 97.146%
#     wait time: 0:00:00.611804s
#
#
#     row: 3848, total_rows: 3960
#     progress: 97.172%
#     wait time: 0:00:00.606407s
#
#
#     row: 3849, total_rows: 3960
#     progress: 97.197%
#     wait time: 0:00:00.600952s
#
#
#     row: 3850, total_rows: 3960
#     progress: 97.222%
#     wait time: 0:00:00.595584s
#
#
#     row: 3851, total_rows: 3960
#     progress: 97.247%
#     wait time: 0:00:00.590186s
#
#
#     row: 3852, total_rows: 3960
#     progress: 97.273%
#     wait time: 0:00:00.584732s
#
#
#     row: 3853, total_rows: 3960
#     progress: 97.298%
#     wait time: 0:00:00.579306s
#
#
#     row: 3854, total_rows: 3960
#     progress: 97.323%
#     wait time: 0:00:00.573909s
#
#
#     row: 3855, total_rows: 3960
#     progress: 97.348%
#     wait time: 0:00:00.568538s
#
#
#     row: 3856, total_rows: 3960
#     progress: 97.374%
#     wait time: 0:00:00.563085s
#
#
#     row: 3857, total_rows: 3960
#     progress: 97.399%
#     wait time: 0:00:00.557686s
#
#
#     row: 3858, total_rows: 3960
#     progress: 97.424%
#     wait time: 0:00:00.552261s
#
#
#     row: 3859, total_rows: 3960
#     progress: 97.449%
#     wait time: 0:00:00.546810s
#
#
#     row: 3860, total_rows: 3960
#     progress: 97.475%
#     wait time: 0:00:00.541385s
#
#
#     row: 3861, total_rows: 3960
#     progress: 97.5%
#     wait time: 0:00:00.535987s
#
#
#     row: 3862, total_rows: 3960
#     progress: 97.525%
#     wait time: 0:00:00.530537s
#
#
#     row: 3863, total_rows: 3960
#     progress: 97.551%
#     wait time: 0:00:00.525138s
#
#
#     row: 3864, total_rows: 3960
#     progress: 97.576%
#     wait time: 0:00:00.519714s
#
#
#     row: 3865, total_rows: 3960
#     progress: 97.601%
#     wait time: 0:00:00.514315s
#
#
#     row: 3866, total_rows: 3960
#     progress: 97.626%
#     wait time: 0:00:00.508916s
#
#
#     row: 3867, total_rows: 3960
#     progress: 97.652%
#     wait time: 0:00:00.503468s
#
#
#     row: 3868, total_rows: 3960
#     progress: 97.677%
#     wait time: 0:00:00.498044s
#
#
#     row: 3869, total_rows: 3960
#     progress: 97.702%
#     wait time: 0:00:00.492645s
#
#
#     row: 3870, total_rows: 3960
#     progress: 97.727%
#     wait time: 0:00:00.487221s
#
#
#     row: 3871, total_rows: 3960
#     progress: 97.753%
#     wait time: 0:00:00.481845s
#
#
#     row: 3872, total_rows: 3960
#     progress: 97.778%
#     wait time: 0:00:00.476467s
#
#
#     row: 3873, total_rows: 3960
#     progress: 97.803%
#     wait time: 0:00:00.471043s
#
#
#     row: 3874, total_rows: 3960
#     progress: 97.828%
#     wait time: 0:00:00.465642s
#
#
#     row: 3875, total_rows: 3960
#     progress: 97.854%
#     wait time: 0:00:00.460197s
#
#
#     row: 3876, total_rows: 3960
#     progress: 97.879%
#     wait time: 0:00:00.454730s
#
#
#     row: 3877, total_rows: 3960
#     progress: 97.904%
#     wait time: 0:00:00.449372s
#
#
#     row: 3878, total_rows: 3960
#     progress: 97.929%
#     wait time: 0:00:00.443950s
#
#
#     row: 3879, total_rows: 3960
#     progress: 97.955%
#     wait time: 0:00:00.438569s
#
#
#     row: 3880, total_rows: 3960
#     progress: 97.98%
#     wait time: 0:00:00.433167s
#
#
#     row: 3881, total_rows: 3960
#     progress: 98.005%
#     wait time: 0:00:00.427764s
#
#
#     row: 3882, total_rows: 3960
#     progress: 98.03%
#     wait time: 0:00:00.422381s
#
#
#     row: 3883, total_rows: 3960
#     progress: 98.056%
#     wait time: 0:00:00.416958s
#
#
#     row: 3884, total_rows: 3960
#     progress: 98.081%
#     wait time: 0:00:00.411554s
#
#
#     row: 3885, total_rows: 3960
#     progress: 98.106%
#     wait time: 0:00:00.406131s
#
#
#     row: 3886, total_rows: 3960
#     progress: 98.131%
#     wait time: 0:00:00.400747s
#
#
#     row: 3887, total_rows: 3960
#     progress: 98.157%
#     wait time: 0:00:00.395323s
#
#
#     row: 3888, total_rows: 3960
#     progress: 98.182%
#     wait time: 0:00:00.389900s
#
#
#     row: 3889, total_rows: 3960
#     progress: 98.207%
#     wait time: 0:00:00.384496s
#
#
#     row: 3890, total_rows: 3960
#     progress: 98.232%
#     wait time: 0:00:00.379109s
#
#
#     row: 3891, total_rows: 3960
#     progress: 98.258%
#     wait time: 0:00:00.373686s
#
#
#     row: 3892, total_rows: 3960
#     progress: 98.283%
#     wait time: 0:00:00.368263s
#
#
#     row: 3893, total_rows: 3960
#     progress: 98.308%
#     wait time: 0:00:00.362857s
#
#
#     row: 3894, total_rows: 3960
#     progress: 98.333%
#     wait time: 0:00:00.357452s
#
#
#     row: 3895, total_rows: 3960
#     progress: 98.359%
#     wait time: 0:00:00.352029s
#
#
#     row: 3896, total_rows: 3960
#     progress: 98.384%
#     wait time: 0:00:00.346590s
#
#
#     row: 3897, total_rows: 3960
#     progress: 98.409%
#     wait time: 0:00:00.341184s
#
#
#     row: 3898, total_rows: 3960
#     progress: 98.434%
#     wait time: 0:00:00.335762s
#
#
#     row: 3899, total_rows: 3960
#     progress: 98.46%
#     wait time: 0:00:00.330356s
#
#
#     row: 3900, total_rows: 3960
#     progress: 98.485%
#     wait time: 0:00:00.324949s
#
#
#     row: 3901, total_rows: 3960
#     progress: 98.51%
#     wait time: 0:00:00.319527s
#
#
#     row: 3902, total_rows: 3960
#     progress: 98.535%
#     wait time: 0:00:00.314150s
#
#
#     row: 3903, total_rows: 3960
#     progress: 98.561%
#     wait time: 0:00:00.308742s
#
#
#     row: 3904, total_rows: 3960
#     progress: 98.586%
#     wait time: 0:00:00.303319s
#
#
#     row: 3905, total_rows: 3960
#     progress: 98.611%
#     wait time: 0:00:00.297911s
#
#
#     row: 3906, total_rows: 3960
#     progress: 98.636%
#     wait time: 0:00:00.292503s
#
#
#     row: 3907, total_rows: 3960
#     progress: 98.662%
#     wait time: 0:00:00.287067s
#
#
#     row: 3908, total_rows: 3960
#     progress: 98.687%
#     wait time: 0:00:00.281632s
#
#
#     row: 3909, total_rows: 3960
#     progress: 98.712%
#     wait time: 0:00:00.276211s
#
#
#     row: 3910, total_rows: 3960
#     progress: 98.737%
#     wait time: 0:00:00.270802s
#
#
#     row: 3911, total_rows: 3960
#     progress: 98.763%
#     wait time: 0:00:00.265406s
#
#
#     row: 3912, total_rows: 3960
#     progress: 98.788%
#     wait time: 0:00:00.259997s
#
#
#     row: 3913, total_rows: 3960
#     progress: 98.813%
#     wait time: 0:00:00.254587s
#
#
#     row: 3914, total_rows: 3960
#     progress: 98.838%
#     wait time: 0:00:00.249166s
#
#
#     row: 3915, total_rows: 3960
#     progress: 98.864%
#     wait time: 0:00:00.243756s
#
#
#     row: 3916, total_rows: 3960
#     progress: 98.889%
#     wait time: 0:00:00.238323s
#
#
#     row: 3917, total_rows: 3960
#     progress: 98.914%
#     wait time: 0:00:00.232891s
#
#
#     row: 3918, total_rows: 3960
#     progress: 98.939%
#     wait time: 0:00:00.227460s
#
#
#     row: 3919, total_rows: 3960
#     progress: 98.965%
#     wait time: 0:00:00.222050s
#
#
#     row: 3920, total_rows: 3960
#     progress: 98.99%
#     wait time: 0:00:00.216641s
#
#
#     row: 3921, total_rows: 3960
#     progress: 99.015%
#     wait time: 0:00:00.211230s
#
#
#     row: 3922, total_rows: 3960
#     progress: 99.04%
#     wait time: 0:00:00.205810s
#
#
#     row: 3923, total_rows: 3960
#     progress: 99.066%
#     wait time: 0:00:00.200381s
#
#
#     row: 3924, total_rows: 3960
#     progress: 99.091%
#     wait time: 0:00:00.194961s
#
#
#     row: 3925, total_rows: 3960
#     progress: 99.116%
#     wait time: 0:00:00.189569s
#
#
#     row: 3926, total_rows: 3960
#     progress: 99.141%
#     wait time: 0:00:00.184158s
#
#
#     row: 3927, total_rows: 3960
#     progress: 99.167%
#     wait time: 0:00:00.178747s
#
#
#     row: 3928, total_rows: 3960
#     progress: 99.192%
#     wait time: 0:00:00.173335s
#
#
#     row: 3929, total_rows: 3960
#     progress: 99.217%
#     wait time: 0:00:00.167907s
#
#
#     row: 3930, total_rows: 3960
#     progress: 99.242%
#     wait time: 0:00:00.162503s
#
#
#     row: 3931, total_rows: 3960
#     progress: 99.268%
#     wait time: 0:00:00.157098s
#
#
#     row: 3932, total_rows: 3960
#     progress: 99.293%
#     wait time: 0:00:00.151692s
#
#
#     row: 3933, total_rows: 3960
#     progress: 99.318%
#     wait time: 0:00:00.146264s
#
#
#     row: 3934, total_rows: 3960
#     progress: 99.343%
#     wait time: 0:00:00.140844s
#
#
#     row: 3935, total_rows: 3960
#     progress: 99.369%
#     wait time: 0:00:00.135425s
#
#
#     row: 3936, total_rows: 3960
#     progress: 99.394%
#     wait time: 0:00:00.129999s
#
#
#     row: 3937, total_rows: 3960
#     progress: 99.419%
#     wait time: 0:00:00.124592s
#
#
#     row: 3938, total_rows: 3960
#     progress: 99.444%
#     wait time: 0:00:00.119178s
#
#
#     row: 3939, total_rows: 3960
#     progress: 99.47%
#     wait time: 0:00:00.113764s
#
#
#     row: 3940, total_rows: 3960
#     progress: 99.495%
#     wait time: 0:00:00.108355s
#     row: 3941, total_rows: 3960
#     progress: 99.52%
#     wait time: 0:00:00.102949s
#
#
#     row: 3942, total_rows: 3960
#     progress: 99.545%
#     wait time: 0:00:00.097538s
#
#
#     row: 3943, total_rows: 3960
#     progress: 99.571%
#     wait time: 0:00:00.092126s
#
#
#     row: 3944, total_rows: 3960
#     progress: 99.596%
#     wait time: 0:00:00.086701s
#
#
#     row: 3945, total_rows: 3960
#     progress: 99.621%
#     wait time: 0:00:00.081285s
#
#
#     row: 3946, total_rows: 3960
#     progress: 99.646%
#     wait time: 0:00:00.075864s
#
#
#     row: 3947, total_rows: 3960
#     progress: 99.672%
#     wait time: 0:00:00.070438s
#
#
#     row: 3948, total_rows: 3960
#     progress: 99.697%
#     wait time: 0:00:00.065018s
#
#
#     row: 3949, total_rows: 3960
#     progress: 99.722%
#     wait time: 0:00:00.059601s
#
#
#     row: 3950, total_rows: 3960
#     progress: 99.747%
#     wait time: 0:00:00.054182s
#
#
#     row: 3951, total_rows: 3960
#     progress: 99.773%
#     wait time: 0:00:00.048761s
#
#
#     row: 3952, total_rows: 3960
#     progress: 99.798%
#     wait time: 0:00:00.043342s
#
#
#     row: 3953, total_rows: 3960
#     progress: 99.823%
#     wait time: 0:00:00.037927s
#
#
#     row: 3954, total_rows: 3960
#     progress: 99.848%
#     wait time: 0:00:00.032508s
#
#
#     row: 3955, total_rows: 3960
#     progress: 99.874%
#     wait time: 0:00:00.027091s
#
#
#     row: 3956, total_rows: 3960
#     progress: 99.899%
#     wait time: 0:00:00.021673s
#
#
#     row: 3957, total_rows: 3960
#     progress: 99.924%
#     wait time: 0:00:00.016255s
#
#
#     row: 3958, total_rows: 3960
#     progress: 99.949%
#     wait time: 0:00:00.010837s
#
#
#     row: 3959, total_rows: 3960
#     progress: 99.975%
#     wait time: 0:00:00.005418s
#
#
#     row: 3960, total_rows: 3960
#     progress: 100.0%
#     wait time: 0:00:00s

# %%
df_representation = pd.DataFrame(data_all_attributes).set_index("id").fillna(0)
df_representation
# Out:
#        retro<&>num_tokens  retro<&>lenght  retro<&>num_numbs  \
# id
# 10000                  18              96                  0
# 10001                  23             119                  0
# 10002                  19             108                  0
# 10003                  24             134                  0
# 10004                  24             125                  0
# ...                   ...             ...                ...
# 40855                  24             112                  0
# 40856                  20             121                  0
# 40857                  23             139                  0
# 40858                  14              83                  2
# 40859                  20             142                  0
#
#        retro<&>num_alpha  retro<&>num_with_uppercase  \
# id
# 10000                 18                           3
# 10001                 25                           7
# 10002                 19                           2
# 10003                 23                           1
# 10004                 25                           3
# ...                  ...                         ...
# 40855                 23                           2
# 40856                 21                           1
# 40857                 23                           2
# 40858                 15                           5
# 40859                 20                           2
#
#        retro<&>num_tokens_upper  retro<&>prop_vowels  \
# id
# 10000                         1             0.253165
# 10001                         2             0.329897
# 10002                         2             0.333333
# 10003                         1             0.315315
# 10004                         0             0.352941
# ...                         ...                  ...
# 40855                         1             0.325843
# 40856                         0             0.352941
# 40857                         1             0.316239
# 40858                         1             0.285714
# 40859                         0             0.349593
#
#        retro<&>len_max_rep_char  retro<&>max_char_fre_per_token(o)  \
# id
# 10000                         2                                  2
# 10001                         2                                  2
# 10002                         2                                  3
# 10003                         2                                  1
# 10004                         2                                  1
# ...                         ...                                ...
# 40855                         2                                  2
# 40856                         2                                  1
# 40857                         2                                  2
# 40858                         2                                  1
# 40859                         2                                  1
#
#        retro<&>max_char_fre_per_token(s)  ...  linguistics<&>lemma<&>scritche  \
# id                                        ...
# 10000                                  1  ...                             0.0
# 10001                                  2  ...                             0.0
# 10002                                  2  ...                             0.0
# 10003                                  2  ...                             0.0
# 10004                                  0  ...                             0.0
# ...                                  ...  ...                             ...
# 40855                                  2  ...                             0.0
# 40856                                  3  ...                             0.0
# 40857                                  4  ...                             0.0
# 40858                                  1  ...                             0.0
# 40859                                  2  ...                             0.0
#
#        linguistics<&>lemma<&>loud,\n#amndbot  linguistics<&>lemma<&>randomly  \
# id
# 10000                                    0.0                             0.0
# 10001                                    0.0                             0.0
# 10002                                    0.0                             0.0
# 10003                                    0.0                             0.0
# 10004                                    0.0                             0.0
# ...                                      ...                             ...
# 40855                                    0.0                             1.0
# 40856                                    0.0                             0.0
# 40857                                    0.0                             0.0
# 40858                                    0.0                             0.0
# 40859                                    0.0                             0.0
#
#        linguistics<&>lemma<&>essay  linguistics<&>lemma<&>concession  \
# id
# 10000                          0.0                               0.0
# 10001                          0.0                               0.0
# 10002                          0.0                               0.0
# 10003                          0.0                               0.0
# 10004                          0.0                               0.0
# ...                            ...                               ...
# 40855                          1.0                               0.0
# 40856                          0.0                               0.0
# 40857                          0.0                               1.0
# 40858                          0.0                               0.0
# 40859                          0.0                               0.0
#
#        linguistics<&>lemma<&>shortsightedness  \
# id
# 10000                                     0.0
# 10001                                     0.0
# 10002                                     0.0
# 10003                                     0.0
# 10004                                     0.0
# ...                                       ...
# 40855                                     0.0
# 40856                                     0.0
# 40857                                     1.0
# 40858                                     0.0
# 40859                                     0.0
#
#        linguistics<&>lemma<&>@keitholbermann  \
# id
# 10000                                    0.0
# 10001                                    0.0
# 10002                                    0.0
# 10003                                    0.0
# 10004                                    0.0
# ...                                      ...
# 40855                                    0.0
# 40856                                    0.0
# 40857                                    0.0
# 40858                                    0.0
# 40859                                    1.0
#
#        linguistics<&>lemma<&>despicable  linguistics<&>lemma<&>rancour  \
# id
# 10000                               0.0                            0.0
# 10001                               0.0                            0.0
# 10002                               0.0                            0.0
# 10003                               0.0                            0.0
# 10004                               0.0                            0.0
# ...                                 ...                            ...
# 40855                               0.0                            0.0
# 40856                               0.0                            0.0
# 40857                               0.0                            0.0
# 40858                               0.0                            0.0
# 40859                               1.0                            1.0
#
#        linguistics<&>lemma<&>immoral
# id
# 10000                            0.0
# 10001                            0.0
# 10002                            0.0
# 10003                            0.0
# 10004                            0.0
# ...                              ...
# 40855                            0.0
# 40856                            0.0
# 40857                            0.0
# 40858                            0.0
# 40859                            1.0
#
# [3960 rows x 11750 columns]

# %%
partition_attrib = {
    type_attrib: [c for c in df_representation.columns if type_attrib+"<&>" in c]
    for type_attrib in "retro punct emoji linguistics".split()
}

# %%
"summary type attrib", {k: len(v) for k, v in partition_cols.items()}
# Out:
# ('summary type attrib',
#  {'retro': 13, 'punct': 7, 'emoji': 190, 'linguistics': 11540})
